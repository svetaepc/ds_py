# %% [markdown]
# <a href="https://colab.research.google.com/github/svetaepc/ds_py/blob/master/text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Char-based text generation with LSTM

# %%
from collections import Counter

import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %% [markdown]
# ## 1. Готовим данные для сети
# Токенизируем текст. Превращаем его в индексы. Т.е. достаем все уникальные символы: буквы, пробелы, знаки препинания в тексте и каждому символу присваиваем число.
# Это будем называть словарем. А числа — индексами.
#
# Делаем прямой и обратный (индексы в символы) словарь. А потом проходимся по всему тексту и превращаем с помощью составленного нами словаря каждый символ в индекс.

# %% [markdown]
# Привет, как дел
# ривет, как дела

# %%
TRAIN_TEXT_FILE_PATH = 'train_text.txt'

with open(TRAIN_TEXT_FILE_PATH) as text_file:
    text_sample = text_file.readlines()
text_sample = ' '.join(text_sample)

def text_to_seq(text_sample):
    char_counts = Counter(text_sample)
    char_counts = sorted(char_counts.items(), key = lambda x: x[1], reverse=True)

    sorted_chars = [char for char, _ in char_counts]
    print(sorted_chars)
    char_to_idx = {char: index for index, char in enumerate(sorted_chars)}
    idx_to_char = {v: k for k, v in char_to_idx.items()}
    sequence = np.array([char_to_idx[char] for char in text_sample])

    return sequence, char_to_idx, idx_to_char

sequence, char_to_idx, idx_to_char = text_to_seq(text_sample)
# Out:
# [' ', '\n', 'о', 'а', 'е', 'т', 'и', 'н', 'л', 'с', 'р', 'в', 'к', 'у', 'д', 'м', 'п', 'ь', 'я', 'ы', '.', 'й', 'г', 'б', 'з', ',', 'ч', 'ж', 'х', 'ш', 'ю', '!', 'П', 'С', 'В', '…', 'Н', '—', 'ц', 'К', '?', 'О', 'Т', 'М', 'Д', 'Г', 'И', 'З', 'Б', 'Л', 'А', 'щ', '-', ':', '»', '«', 'У', 'Р', 'Ч', 'Х', 'э', 'Я', 'Ж', 'ф', 'Е', '*', 'Ш', 'Ф', 'Э', 'ё', '–', 'Ц', 'e', '0', 'o', 'ъ', 't', 'a', '(', 'n', 'k', ')', 'C', 'X', 'r', '"', 'Й', 'c', 'Щ', "'", 'p', 'm', 'Ь', 's', 'i', '9', '1', 'w', 'B', 'M', 'd', '2', 'Ю', 'N', 'b', 'u', 'D', 'l', 'K', 'Ё', 'V', 'R', 'h', 'U', 'I', '<', '8', '4', '#', 'H', '6', '7']

# %% [markdown]
# ## 2. Генерируем батчи из текста
# Генерируем из последовательности наших индексов батчи (сразу несколько строк текста) для обучения сети. Не будем усложнять, просто достанем несколько случайных строк из текста фиксированной длины.
#
# Будем генерировать сразу обучающую выборку (то, на чем будем учить сеть) и таргет для нее. Таргет (правильные ответы для нейросети) — это просто сдвинутый на один символ вперед текст.

# %%
SEQ_LEN = 256
BATCH_SIZE = 16


# `get_batch()`, которая возвращает пару тензоров `torch.stack(trains, dim=0)` и `torch.stack(targets, dim=0)`.
def get_batch(sequence):
    """Переменная `sequence` является последовательностью элементов,
    которые должны быть разбиты на куски длиной `SEQ_LEN`.
    Переменная `BATCH_SIZE` определяет число кусков, которые должны быть сгенерированы.
    Каждый кусок включает в себя `SEQ_LEN` элементов.
    """
    trains = []
    targets = []
    for _ in range(BATCH_SIZE):
        """Затем в цикле `for` генерируются `BATCH_SIZE` кусков, для каждого из
        которых сначала генерируется случайный начальный индекс `batch_start`
        от `0` до `len(sequence) - SEQ_LEN` и берется подпоследовательность
        `chunk` длиной `SEQ_LEN` начиная с `batch_start`
        """
        batch_start = np.random.randint(0, len(sequence) - SEQ_LEN)
        chunk = sequence[batch_start: batch_start + SEQ_LEN]
        """Далее, из данной подпоследовательности, создается тензор `train`
        из элементов `chunk[:-1]` (используется срез от начала до последнего элемента),
        и тензор `target` из элементов `chunk[1:]`
         (используется срез от второго элемента до конца) """
        train = torch.LongTensor(chunk[:-1]).view(-1, 1)
        target = torch.LongTensor(chunk[1:]).view(-1, 1)
        trains.append(train)
        targets.append(target)
        """возвращает пару тензоров `torch.stack(trains, dim=0)`
        и `torch.stack(targets, dim=0)`, которые являются стеком тензоров `train`
         и `target` по первому измерению (ось 0), т.е. получается тензор размера
         `(BATCH_SIZE, SEQ_LEN-1, 1)` для `train` и `(BATCH_SIZE, SEQ_LEN-1, 1)` для `target`"""
    return torch.stack(trains, dim=0), torch.stack(targets, dim=0)

# %% [markdown]
# ## 3. Пишем функцию, которая генерирует текст
# Теперь напишем функцию, которая предсказывает текст с помощью нашей обученной нейросети. Это удобно сделать заранее, чтобы смотреть, что генерирует сеть во время обучения.
#
# Сеть предсказывает нам вероятности следующей буквы, и мы с помощью этих вероятностей достаем случайно по одной букве. Если повторить операцию 1000 раз, получим текст из 1000 символов.
#
# Параметр start_text нам нужен, чтобы было что-то, для чего предсказывать следующий символ. У нас этот символ по умолчанию — пробел, и задача сети сначала — предсказать следующий символ после пробела. Потом — следующий после этих 2-х символов. И т.д.
#
# Параметр temp — это уровень «случайности» генерируемого текста. Так называемая «температура» с отсылкой к понятию «энтропии». То, на что делим логиты в softmax. Поставим высокую — вероятность каждой буквы будет почти одинакова и текст превратится в случайную белиберду. Поставим низкую — каждый раз будем предсказывать одно и то же и можем зациклиться на одной фразе.

# %%
def evaluate(model, char_to_idx, idx_to_char, start_text=' ', prediction_len=200, temp=0.3):
    hidden = model.init_hidden()
    idx_input = [char_to_idx[char] for char in start_text]
    train = torch.LongTensor(idx_input).view(-1, 1, 1).to(device)
    predicted_text = start_text

    _, hidden = model(train, hidden)

    inp = train[-1].view(-1, 1, 1)

    for i in range(prediction_len):
        output, hidden = model(inp.to(device), hidden)
        output_logits = output.cpu().data.view(-1)
        p_next = F.softmax(output_logits / temp, dim=-1).detach().cpu().data.numpy()
        top_index = np.random.choice(len(char_to_idx), p=p_next)
        inp = torch.LongTensor([top_index]).view(-1, 1, 1).to(device)
        predicted_char = idx_to_char[top_index]
        predicted_text += predicted_char

    return predicted_text

# %% [markdown]
# ## 4. Создаем класс нашей нейросети
#
# 1. Превращаем каждый символ на входе сети в вектор (так называемный эмбеддинг).
# 2. Скармливаем эти векторы нашему LSTM слою. У этого слоя есть особенность: он работает не независимо для каждого символа, а помнит, что к нему раньше приходило на вход. Притом, помнит не все: ненужное он умеет забывать. Такие слои называют рекуррентными и часто используют при работе с последовательностями.
# 3. Выходы из LSTM слоя пропускаем через Dropout. Этот слой «мешает» сети учиться, чтобы ей сложнее было выучить весть текст.
# 4. Дальше отправляем выход из Dropout на линейный слой размерности словаря, чтобы на выходе получить столько чисел, сколько у нас символов в словаре. Потом мы этот вектор чисел будем превращать в «вероятности» каждого символа с помощью функции softmax.

# %%
class TextRNN(nn.Module):

    def __init__(self, input_size, hidden_size, embedding_size, n_layers=1):
        super(TextRNN, self).__init__()

        self.input_size = input_size
        self.hidden_size = hidden_size
        self.embedding_size = embedding_size
        self.n_layers = n_layers

        self.encoder = nn.Embedding(self.input_size, self.embedding_size)
        self.lstm = nn.LSTM(self.embedding_size, self.hidden_size, self.n_layers)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(self.hidden_size, self.input_size)

    def forward(self, x, hidden):
        x = self.encoder(x).squeeze(2)
        out, (ht1, ct1) = self.lstm(x, hidden)
        out = self.dropout(out)
        x = self.fc(out)
        return x, (ht1, ct1)

    def init_hidden(self, batch_size=1):
        return (torch.zeros(self.n_layers, batch_size, self.hidden_size, requires_grad=True).to(device),
               torch.zeros(self.n_layers, batch_size, self.hidden_size, requires_grad=True).to(device))

# %% [markdown]
# ## 5. Создаем нейросеть и обучаем ее
# Теперь создаем нейросеть и обучаем ее. LSTM блок принимает немного другой формат батча:
#
# [SEQ_LEN x BATCH_SIZE x 1], поэтому делаем permute для тензоров train и target, чтобы поменять 0 и 1 размерность местами.
#
# Параметры нейросети, которые может понадобиться подкрутить:
#
# - hidden_size — влияет на сложность сети. Стоит повышать для текстов большого размера. Если выставить большое значение для текста маленького размера, то сеть просто выучит весь текст и будет генерировать его же.
# - n_layers — опять же, влияет на сложность сети. Грубо говоря, позволяет делать несколько LSTM слоев подряд просто меняя эту цифру.
# - embedding_size — размер обучаемого эмбеддинга. Можно выставить в несколько раз меньше размера словаря (числа уникальных символов в тексте) или примерно такой же. Больше — нет смысла.
# Дальше — стандартный для PyTorch цикл обучения нейросети: выбираем функцию потерь, оптимизатор и настраиваем расписание, по которому меняем шаг оптимизатора. В нашем случае снижаем шаг в 2 раза, если ошибка (loss) не падает 5 шагов подряд.

# %%
# %%time
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model = TextRNN(input_size=len(idx_to_char), hidden_size=128, embedding_size=128, n_layers=2)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2, amsgrad=True)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    patience=5,
    verbose=True,
    factor=0.5
)

n_epochs = 100000
loss_avg = []

for epoch in range(n_epochs):
    model.train()
    train, target = get_batch(sequence)
    train = train.permute(1, 0, 2).to(device)
    target = target.permute(1, 0, 2).to(device)
    hidden = model.init_hidden(BATCH_SIZE)

    output, hidden = model(train, hidden)
    loss = criterion(output.permute(1, 2, 0), target.squeeze(-1).permute(1, 0))

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

    loss_avg.append(loss.item())
    if len(loss_avg) >= 50:
        mean_loss = np.mean(loss_avg)
        print(f'Loss: {mean_loss}')
        scheduler.step(mean_loss)
        loss_avg = []
        model.eval()
        predicted_text = evaluate(model, char_to_idx, idx_to_char)
        print(predicted_text)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#
#  уж не осталось
#  не замерзнут ли?
#
#  Вот скоро уходит
#  Станик в темноте —
#  что улыбнетс
# Loss: 0.6367264187335968
#  —
#  была начнется сорный бола
#  Стоит ли любить?
#
#  Совсем не Байрон.
#  и слог в ладонец. Давору кувший
#  Друг все ближе на луну.
#  Столько хлопотом
#
#  света. Путь на светвет
#  Под сакурою
#
#  Порножурналы
#
# Loss: 0.6384252464771271
#  —
#  поздняя осень
#
#  Порножурналы
#  В положный помню,
#  Пойти напиться?
#
#  Старый ветерок?
#  Вот тебе и май…
#
#  Лето на дворе…
#  Перва саморгалось карто,
#  Если под снегом.
#
#  Стоит ли любить?
#  Стоит ли люб
# Loss: 0.638322058916092
#  —
#  весна на дворе…
#
#  Осень на дворе…
#  Партии моей парус
#
#  Поймали вода.
#  Хотел на мог ябина
#  Милая в саду лесной
#  Как отрезало глячь насущив
#  не то что такая вихон
#  Проснулся в поле.
#
#  Старый крика
# Loss: 0.6401946234703064
#  Сегуна спасил
#  но не был корей!
#
#  полно простое —
#  По склону холма. быстрей
#  pолзи, улитка!
#
#  Весенний дождь.
#  Вот приходит не спросил:
#  но раз поздни — не доволен
#  Странно все это!
#
#  Одевать «мини
# Loss: 0.6363150131702423
#  на самурай.
#  И положен и бвих муду.
#  Проснулся в поле.
#
#  Старый вижу
#  по склону Фудзи взглядой
#  Какое лисьеть но не ветер
#  С деревоб с травке утром
#  Завтрак на воле
#
#  В положно пьет мне
#  Толка, лицо
# Loss: 0.6379099380970001
#  саду
#  Нет места смерти
#
#  Осень скорей, и
#  лететь здорово!
#
#  Над Фуджи закрыта
#  случился сон лежит.
#
#  В добросил в подник лиц
#  Потому поселюсь.
#
#  Может и в ухо…
#  Веселили растога больше
#  Пришла он
# Loss: 0.6347139930725098
#  давать цикады
#  совется в море —
#  подводят висидиного
#  Давай вечером
#
#  ты в моем сердце
#  в садил смертли замеревьми
#  и стало получег.
#
#  Ты стран столовил
#  Но не устанет
#
#  По болит, не тебе
#  под оста
# Loss: 0.6351085615158081
#  —
#  твой свежей короткий!
#
#  Посмотри Ду-Фу,
#  Как словал я по поляться,
#  Солнце не нужен носа
#  Загонов море из
#  Гадит собака
#
#  Проснулся в полты.
#  Столько хлот не нужен…
#
#  Молоды — носде
#  И промошел
# Loss: 0.6356776559352875
#  напиться?
#
#  Себя услаждать.
#  Долгий день на столе.
#  Сто положеньи кирик
#  Не помню поставить
#  весь на долго тут…
#
#  Вот тебе и май…
#
#  Заплатила добы и
#  не в полна смотрит
#  Слушать мне так не стоит.
#
# Loss: 0.6393180716037751
#  бабку
#
#  на ноге бомжа
#  по во мотели приглочка.
#
#  Что глупости в ночи моим!
#  Напрачно, с какой тебе — винка.
#  Проснулся в поту
#  Где дидение…
#
#  Островки борозда
#  ночь та. ступай же.
#
#  Так ярко горит
# Loss: 0.6363164150714874
#  пастоль мать! —
#  стал ищинзаны
#
#  Где твое кравший —
#  Третьего дня
#
#  Придень в поле.
#
#  После постелись в подних доме
#  Не дашь. Я знаю.
#
#  Вот приходит нестой мир —
#  по дороге на свете
#  Сочинял хокку
# Loss: 0.6428386628627777
#  Сегун
#  Под сакурою
#
#  Поднимусь и все вся,
#  Осень на дворе…
#
#  Старик прял пряжу.
#  Большего хочу!
#
#  Весенний день.
#  Островает красный деревья в засолькой
#  С тобой пейзаж ветка —
#  Вот безавше задни.
#
# Loss: 0.6416151082515716
#  —
#  поздняя осень
#
#  Порножурналы
#  В оставить наславной
#  Перекресток вечером
#  Облака плывут.
#
#  Прохладный ветер
#  Странник небесы.
#
#  Посмотри Ду-Фу,
#  Как сказывали тужась,
#  Солнышелся вспомина,
#  Пойма
# Loss: 0.6439627170562744
#  веселом.
#
#  Старый правтра
#
#  Голос модема!
#  От стрелки киплеск
#
#  В зеркало гляжусь:
#  На солдно. Сад веткас
#  Нет места и холод травика.
#
#  Море лечал я запор.
#  Тоже мне так уж прекрасна.
#  Холод верши
# Loss: 0.6376539134979248
#  —
#  после наботине, что тут витрая —
#  Светлую любовья
#
#  В зеркало гляжусь:
#  Солову портите
#
#  После ползи, и бы мой столя
#  тоже самой хокку
#
#  В зеркало гляжусь:
#  Молоды на ветру.
#  А ты, кошал кушает
#
# Loss: 0.6420223689079285
#  — как свои картыни
#  Славную глаза —
#  под забыв в застило вномкой
#  Гораздо плывать — чуть
#  Мне не нужны за водку
#  Паутину, мох
#
#  Посмотри скорей
#  по ночам отмад
#
#  Пролетарии
#  в полю он вот вишней?
#
#
# Loss: 0.6400065386295318
#  веселом.
#
#  Грустно способна
#  Под сакурою
#
#  После после полях ли
#  На ноге бомжа
#
#  полножунали?
#  сновидением
#
#  Не повестрой!
#  Под трак не заре Ноя вечер.
#  Лето на дворе…
#
#  После после полях ли
#  Сле
# Loss: 0.6334264421463013
#  Алеца
#
#  В положный по тебе
#  Пропил сапоги.
#
#  Пророс, запил под травку
#  А зачем, милый?
#
#  Переносную.
#  Скучно тут в Штатах.
#
#  Дом вспомнил родной
#  Под сакурою
#
#  Пойду на него
#  Так тала то стихой в
# Loss: 0.6397786951065063
#  веселом.
#
#  Старый виня,
#  Что Д. Путетили мне
#
#  воскликнул Пихто:
#  Какой рассказ в он крытий!
#
#  Пропелы мне
#  воскликнул Пихто:
#  Какой короткий!
#
#  От поцелуев.
#  теперь и попереверевь
#
#  Поднимусь лу
# Loss: 0.6397914779186249
#  саду
#  Под трак не стоит лишь понего
#  глупостянюю что
#
#  Проверяя скрипт
#
#  Как там Воркута?
#  Ворон с другими
#
#  на ложит душа
#  На праздник потановал
#  Шепчет я на волю.
#
#  От поцелуев…
#  Кукушка прошел
# Loss: 0.6429280042648315
#  —
#  поздняя осень.
#
#  Прохладно и дела
#  хотя бы взгляни!
#
#  Что глупости, не
#  остров наша в вершины
#  Вспомнить приятно!
#
#  понял амиго?
#  Ета весна никать реки
#  Вот тебе и май…
#
#  Порнухи звуки
#  (истра
# Loss: 0.6367376947402954
#  —
#  морская врига —
#
#  на берегах Лелу.
#  Себя услаждать.
#
#  Весенний дождь.
#
#  В небе такая луна,
#  Словно дерево спилено под утро
#  Старый правтра
#
#  Стал тон не сповнешься?
#  и уленый парус
#
#  Не повесе
# Loss: 0.6379990482330322
#  —
#  меня все растая
#  Грустная кукушка…
#
#  Посмотри Ду-Фу,
#  Кукушки дальний снегу.
#
#  Порножурналы
#  Выпей газетой
#
#  От геморроя
#  прилег не спросил:
#
#  сновидением
#  вырос его поселюсь.
#
#  Что гильотина,
# Loss: 0.638967958688736
#  веселом.
#
#  Приходи скорей!
#  Стоит ли любить?
#
#  Старый вечер.
#  Лето на дворе.
#
#  Тоский Соган.
#  В сейчай дожди.
#
#  В зеркало гляжусь:
#  Сотрый мило время
#
#  Мне не лекать вечер.
#  Лежачий, стал быть.
#
# Loss: 0.6356832635402679
#  пастоль смолчался.
#  Под утро выгнуть луна,
#  Как там Воркута?
#
#  Любимый во сне
#  Я спросил вождя.
#
#  «Какой короткий!
#  Но полобнит вокруг
#
#  Полный идиот
#  С худощавым мине — ветка —
#  Так ты мне маравы.
# Loss: 0.632553688287735
#  веселом.
#
#  Даже подкову
#  Как дальше жить мне?
#
#  Совсем не Байрон
#  моем сердце
#
#  Пролетарии
#  все равно и не стоит,
#  Если не стоит.
#
#  Прохладно у меня
#  деда порается в Япустын.
#  Да и предлойней —
#  п
# Loss: 0.6394055116176606
#  веселом проснулись
#  Залить Heineken'ом
#  Тоску по тебе…
#
#  То как моестита —
#  Тетереги говорю
#
#  Но моя мысльит!
#  Стану избирать
#  Жентеревом сортир…
#
#  В страшно не надо
#
#  поздняя осень
#  и напирапит.
#
# Loss: 0.6387136363983155
#  —
#  весна на дворе…
#
#  Осень на дворе…
#  Полночь. Там: Он
#  По стоит лишь похором —
#  не то что лошадь круби.
#  Стоит ли любить?
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Совсем старик кукушка…
#  Дык скоро п
# Loss: 0.644962329864502
#  саду.
#  Облака плывут.
#
#  Корова смотрит —
#  поздняя осень!
#
#  Как ты не далетно
#  Сладко поздно
#
#  Почему тебе…
#  Как ты но передать «мини
#  Не вердит повесить
#  Пойти напиться?
#
#  Над Фуджи другому
#  слуха
# Loss: 0.6388885700702667
#  Сегун
#  Под ним – ная любовь
#  Под сторовал ветру.
#  Посмотри скорей!
#
#  Как там Воркута?
#  Волкому махман.
#
#  Нету запаха.
#  Увы, не сядет пчела
#  Никак бравшей малцо
#
#  С ное дикий день, друзья!
#  не замет
# Loss: 0.636446145772934
#  саду
#  Проснулся в поту
#  Где дерево спать бы травы
#  Он не спретенчиво
#  я ж не одна.
#
#  Не получилось
#  Проснешься же в вершины
#  Странно вижа, чусь с
#  Славную память!
#
#  Лето на дворе…
#  Какой не лигра лу
# Loss: 0.6378909409046173
#  веселом.
#
#  Проснулся в поту
#  Етри посеть все раз
#  В подумался в полнобов
#  утропав, мостям, я так, сказал
#  На завтракает
#
#  проверяя скрипт,
#  не поздняя осень
#
#  По скома-то напить простой?
#  Стоит ли
# Loss: 0.64069739818573
#  веселом.
#
#  Старый вине.
#  Не помню паутине.
#  Но ото, что мерзоков —
#  На ночь пристилась в заботать
#  в первые не стоит?
#
#  Пролетарии
#  вернись и жива?
#
#  Опять один я
#  Что глупости, не найрала!
#  Вот те
# Loss: 0.6376545870304108
#  такий вакрездал.
#  я ждился мутока
#  Войду в жало глаз
#  Никто не вечен…
#
#  Над Фудзияме
#  тишина в розей
#
#  Первая хокку
#  Словно карма в невы,
#  А приплыли моей мысь
#
#  вот и вся любовь
#  Странные может…
#
# Loss: 0.6412412667274475
#  веселом.
#
#  Может и в ухо…
#  Вот скоро уходит
#
#  В небе такая —
#  тихий стать могит — не
#  Стоит ли любить?
#
#  В небе такая луна,
#  Словно дерево спилено под корень:
#  Белеет свежий срез.
#
#  Иду играя,
#  Ес
# Loss: 0.636614431142807
#  саду
#  Нет места смерти
#
#  С печальной миной
#  и скрипят на небо —
#  Вот приветешь не стоит?
#
#  Притихли то же так, зловей
#  Полны слезами.
#
#  Старый крикать холма.
#  Полночь. Так и меня
#  Стану из шуда,
#  Н
# Loss: 0.642728716135025
#  веселом.
#
#  Уходи скорей!
#  Небе сеперегзу
#  клин журавлиный мете…
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Летний ночью тропы
#
# Loss: 0.6410462522506714
#  —
#  поднял была ты в жином
#  Мароза в Путь спал к ленять
#  Проверяя скрипт.
#
#  Приходи скорей!
#  Стоит ли любить?
#
#  Совсем не Байрон.
#  На стол упала
#
#  Мало пойду на Тихон
#  Сладко поздно
#
#  сновидением
#
# Loss: 0.6396628248691559
#  такляги,
#  Не повестрой мой столет цветок
#  Смотрит на ныго…
#
#  Разошлись круги…
#  Мать по самого. Прочитав
#  Разбитое подорил красто
#  хотя бы взгляни!
#
#  Что глупости, не —
#  Скрыть на него получей
#  Что ж
# Loss: 0.6462166202068329
#  такаешь мой верне.
#  увидев бедник. Вот и вся листьев
#  Как ты ночью то взолеть,
#  А с Вороневка.
#
#  Стал тень патриарха
#  металась в ней без прошел —
#  После бойся, не съем»
#
#  Сказал Сальери:
#  «Вино-то к
# Loss: 0.6419940340518951
#  —
#  Изучал правду.
#
#  Первая хокку!
#  Вот посетро сделать,
#  Может доктор Чуку» —
#  Видно, дома, минуевной
#  Потрик обыкой короткий!
#
#  После постели мне
#  твой старый пердун
#  Не повестрой вачивший —
#  Весь
# Loss: 0.6360340583324432
#  такие. Но и СПИД сойдет.
#  света. Пус..
#
#  Ставляет светлый
#  Как там Воркута?
#
#  в зеркало гляжусь
#  Я нечасто. А когда
#  совсем не уронились.
#  Молодие вам собою
#  Но просто и не помню
#  После наворонки ка
# Loss: 0.6359288799762726
#  —
#  поздняя осень
#
#  Порножурналы —
#  Потрахаться с тобою
#  Ползи ли, Воно —
#  Проверяя скрипт.
#
#  Близятся такая
#  слезу столько прость
#
#  В окне дрожит душа
#  гейше задремал
#
#  Полнолуния вистой
#  серпели
# Loss: 0.6427304434776306
#  веселом.
#
#  Проглотил прилядущей котела
#  Не повесите море
#  На моя простой мой столет —
#  Весь вечер пишу.
#
#  Плывут в Абакан
#  Распоряжайся!
#
#  Ты помнишь «Сайгон»?
#  Барышнует светер.
#  Поднимают в саду.
# Loss: 0.6359095573425293
#  веселом.
#
#  Может и в ухо…
#  Веселились, но стихи
#  На берег в морковку
#
#  В мыслях о тебе
#  Когда Зимний брать?
#
#  Выплылетелько умей
#  И полна смотрит.
#
#  Проснулся в поту
#  Пленистил концась мне — столб
# Loss: 0.6437430465221405
#  веселом подуть ты
#  Выписьно мне не стоит.
#  Как там Воркута?
#
#  от приботать.
#  Да и пронес вишно?
#  Давай вечером
#
#  все мертво, уйди
#  или нет, нет, не вечер.
#
#  Вот тебе и май!
#  не то с ней светлячок.
#
# Loss: 0.64222034573555
#  веселом.
#
#  Прохладно видеть
#  уж не слушать мы бамбы стоит.
#  Зачем ты пришла?
#
#  Корова мычит
#  Как волон от горане.
#
#  Полночь. Manhattan.
#  Гнусно воет свежайся
#  Вот так и сорей бед дарты.
#  Поздняя ос
# Loss: 0.6391895139217376
#  —
#  поднял была ты в ночи спит.
#  Как волон глядит ли служать
#  Не повестрой столицей
#  Порножурналы
#
#  Ночного света.
#  Лучше похмелье.
#
#  Проснулся в поту
#  Проснулся в поле.
#
#  Старик прял пряжу.
#  Бабка
# Loss: 0.638335645198822
#  —
#  поздняя осень.
#
#  На стол упала
#  прякда поседевших круги
#  В моем сердце
#
#  Перенапрядой
#  Скрылась в туалете
#
#  Проголосовал.
#  я — как японский бог
#
#  Все в селе была в он —
#  под забил как ты ж на в
# Loss: 0.6420776700973511
#  веселом проснулись
#  Сожет дута могло емба
#  и в голос цикады
#
#  От поцелуев…
#  Карма по мутно
#  Помостерег меня.
#
#  Проверяя скрипт,
#  Забить в засаду столя,
#  Бездомную голову
#  в порой карной глаза…
#
#  Ст
# Loss: 0.6362055253982544
#  —
#  поднял была ты в жином
#  Нет места смерти
#
#  Очарована —
#  «Не такой уж скоро
#  проснулся в полно
#  С бухариная совсем
#  почел и вся тебе и в лесу.
#  Какой руки в море —
#  завтра ни дораздри
#  Вот приходит
# Loss: 0.6430940091609955
#  веселом подла горит —
#  Вот тебе и май!
#
#  не доволен я
#  Тешем плыть-то чем в водки
#
#  Смотрю на луну.
#  Корова мычит…
#
#  Проникают.
#  За водки светлой попробевать хо,
#  Так не усну, вок-сту
#  не поздно. Д
# Loss: 0.6397353029251098
#  —
#  проверяя скрипт
#
#  теперь их не съесть
#  дождливый дождь.
#
#  Молодил, и вся, лечись,
#  Что бы согреться
#
#  праздник у друга
#  Осень на дворе…
#
#  Осень на них —
#  недопроверил
#
#  «Прошай, Токио!»
#  стал
# Loss: 0.6425215625762939
#  —
#  морсально перебрал
#
#  сновидением
#  визлой лист беряли
#  по конзина.
#
#  А может, и в он крича,
#  Славную память!
#
#  От самом или гор, шляц
#  Совсем не Байрон.
#
#  Молодие стоит,
#  Приходи скорей!
#
#  Выбр
# Loss: 0.6388937282562256
#  веселом.
#
#  Весенний денек.
#  Зима на дворе…
#
#  В положно пира
#  Совсем не Байрон.
#
#  Но и СПИД сойдет.
#  света. пустой свету
#  Плача, вспоминал…
#
#  «Нет уж одал —
#  «Не бойся, не съем»
#
#  Не поведно. же —
# Loss: 0.6329493403434754
#  Алеца
#  И опять мне тебя
#
#  В мыслях о тебе
#  Перекресток он но
#  Не то что лошадь
#
#  Ухо ласкает
#  совсем ни капли
#
#  Не поздняя осень
#  и на стол упать бы — пытная,
#  Что с невесна не отдалась —
#  Веселили
# Loss: 0.6365390944480896
#  веселом подуть тебе —
#  Не бойся, не съем
#
#  Поднимусь лучше
#  Под сакурою
#
#  Порножурналы
#  В положный привычки.
#
#  Прохладный ветер.
#  На свете сладусь и
#  Проснешлылся ветру!
#
#  Треснула люстра
#  Как сла
# Loss: 0.6369513261318207
#  веселом.
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Старик прял пряжу.
#  Бабка поднила тучный
#  не помню, другей!
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Совсем не Бай
# Loss: 0.6362324106693268
#  —
#  поздняя осень!
#
#  По скоро уходит.
#  Да и прочивал напиться?
#
#  Весенний дождь.
#
#  Что же все в окно.
#  Весь вечер пишу вершина
#  Чаем и кофе.
#
#  Вот тебе и май!
#  не заметился
#  не доволен я
#
#  Никто н
# Loss: 0.6368972527980804
#  Алтовы!
#
#  После постели скрипт.
#  А потом за собственно
#  Нет места смерти
#
#  Осень скорей!
#  пишни по дорогоний столицей
#  Как японский бог
#
#  полная светлый деревья в прядит.
#  Пойду я володой
#  Первая х
# Loss: 0.6411885225772858
#  —
#  поднял я была, не вечер.
#  На носока, «Задит он…
#  Они так вомет на ветке
#  Нету мостик
#
#  Уходи скорей!
#  Если ты в моем сердце
#  все меня весной.
#
#  Ты спрятать хотел
#  Видений глюки.
#
#  Дед садил свек
# Loss: 0.6352190506458283
#  веселом.
#
#  Местечко мостявы,
#  Солное вина.
#
#  В мыслях о тебе
#  Это меня словно
#  От поцелуев…
#
#  Не то что лошадь,
#  Средко приземленной дом
#  И буду или старик
#
#  Уходи скорей!
#  Приснится же такое — св
# Loss: 0.6360198020935058
#  веселом.
#
#  Старый ветерок?
#  Вот старовник воркенье
#  Сменяет среда.
#
#  Вот тебе и май
#  Проснулся в полно
#  Смолкаю совсем
#  по ночам отдавьки
#
#  Портит весь имидж
#  ты в моем сердце
#
#  утоплюсь в море!
#
# Loss: 0.6371091091632843
#  —
#  поздняя осень
#
#  Не помню, для тедь
#  из полная врагов
#  Проснулся в полно
#  С бихтом не помню
#
#  Стал тише воды.
#  Нет, он любви несчастно.
#
#  Излучал правду.
#  Отраса скорей! сапоги
#  теперь их не чест
# Loss: 0.6368831753730774
#  —
#  поднял была, ты не стоит,
#  Если не стоит.
#
#  Проснулся в поту
#  Етри посеть все в море
#  На свете дети осень
#  и на стол упать на ветке
#  На ловец жемчуга
#
#  Поднял я бычок.
#  Не все разобрали
#
#  Просну
# Loss: 0.6443150162696838
#  саду, а?
#  Я — там реки. А терен —
#  Тетерег согнулись.
#
#  Ворон, почивал.
#  Раздался выстрел
#  Вспомнить приятно!
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Старый крикать мне
#  полобнить не стоит.
#  Заколев
# Loss: 0.6362616515159607
#  —
#  поднял я была сама…
#  Ты с другими на дворе…
#  Перва саморгало гляжусь
#  До головокруженья
#  голос цикады
#
#  Привычный пейзаж —
#  Приходи скорей!
#
#  Расположен коме —
#  На ночь тут боздняя друг,
#  Не то ч
# Loss: 0.6450172805786133
#  имах спасиц.
#  То выпал вот и вся бы —
#  под забыл я
#
#  Читал Толстого
#  Дело простое.
#
#  Не поздняя осень
#  и разбежались круги
#
#  волнует козлов
#  поездия меня
#  ты ушла. Тоска.
#
#  Прохладно видеть,
#  Прив
# Loss: 0.6367349982261657
#  —
#  поднимая светлой весна
#  гляжу нам, стихлет.
#
#  Молодил в селеный
#  Стор затарата меж.
#
#  В дождь ты красавиц
#
#  правду изучил
#  Выросла весной
#
#  От насекомых
#  С бегана.
#
#  Ты в моем сердце
#  не замет
# Loss: 0.6345614302158356
#  —
#  поднимая светлой ветвив.
#  Но и СПИД сойдет.
#
#  Проверяя скрипт,
#  Заботах шелесет?
#
#  Он уж в Мекку?
#  Не все ли снегом.
#
#  Корова смотрит.
#  я взоляма —
#  Перена дне нужней
#
#  Тень патриарха
#  металась
# Loss: 0.6374098432064056
#  —
#  Зачем ты пришла?
#  совсем не стоит лишь пони коне
#  Нет, как красивы на дворе…
#  Полные лица
#
#  В мыслях о тебе
#  Даже подарина…
#  Всем вся его посина,
#  Принимали зачем
#  по ноц моя, покойный сторой.
#  По
# Loss: 0.639383749961853
#  пастоль мачно,
#  то в моем сердце
#
#  После постелись
#  Понял, амиго?
#
#  Когда надо спать
#  С делает или ночью.
#  Соловьем ушла
#
#  «в зеркало гляжусь
#
#  Голова свежа
#  сам Так бабочка —
#  Не надо света.
#
#  С
# Loss: 0.6378769385814667
#  — как не смотрий красны…
#  Вишни совсем ни заставил
#  паутину, мох
#
#  Не повесенний ветер
#  Странник пришел?
#
#  ты в моем сердце
#  все мертво, уйди
#
#  от сама — Майфан
#  Станет окной.
#
#  Плача, вспоминал…
#
# Loss: 0.6366840982437134
#  —
#  поднимая светлой ветвив,
#  говорила мне на Мавзорька
#  Чайке старик
#
#  По листьям сухим
#  (Смешно, мне дашь
#
#  по ночал в нев Славший лист
#  В страшных поляться?
#
#  Себя наслаждать
#  Не повестрой коротк
# Loss: 0.6409370183944703
#  Алтовы на светво…
#  Принес весен на ветру.
#  А то получилась в поту
#  Плохой тебе и в ухо…
#  А они в полны слез.
#  Волкнул он виду отму,
#  Ночного света.
#
#  Проснулся в поту
#  Етри дети о нужжен,
#  В подушке
# Loss: 0.6443423867225647
#  пастолчал..
#  Солнынсон лето…
#
#  Старый вечер.
#  Не надо будет нам ни столбы
#  Нет бабе скорей!
#
#  Весенний дождь.
#
#  Что бы согреться
#  Видением в полночь.
#
#  Вот тебе и май…
#
#  Не повесенний страсти.
#  о
# Loss: 0.6361580884456635
#  веселом.
#
#  Проголосовал.
#  Ночь на дворе…
#
#  Старик прял пряжу.
#  Бабка поднила туча,
#  Проголосовал.
#
#  Прохладно у меня
#  деньги я люблю
#
#  В небе такая —
#  по во мор собака.
#
#  Проснулся в поту
#  Просну
# Loss: 0.6361519157886505
#  —
#  подлесть на солнее —
#  Было поздно
#
#  Вечен порядок
#  Что дети ли любить?
#
#  Одевать «мини»
#  Было под засыпал снег.
#  От меня не помню
#
#  После постели мне —
#  Говорил на коленях
#
#  Полночь моя расска
#
# Loss: 0.6355537235736847
#  пастолчал..
#  Собака кричит!
#
#  Стала задницей
#  Куда ж нам плыть-то?..
#
#  Паутину, мох
#  стал под сакурован!
#  Вот смель. Там полнует.
#
#  В мыслях о тебе
#  Стонит сказала
#
#  В положно пью глаз
#  проверяя с
# Loss: 0.6364570844173432
#  —
#  такой старили тумарь
#  Вишен вырас
#
#  «Прошай, Токио!»
#  стал на друга и
#  поставится в полотно
#  Слог в эту строку
#
#  склону в сортир,
#  я с другими…
#
#  Когда надо спать
#  Пока здут ний руки
#  прошедшие
# Loss: 0.6413820254802703
#  —
#  поднял я бычок.
#
#  На стол упала
#  прямо в котерайкли
#
#  Старый правтра
#
#  Стоит ли любить?
#  Старый кричит:
#
#  В страшно тут весна
#  зворать последний бабоку
#  Нет места смерти
#
#  Опять один, что
#  Пое
# Loss: 0.6459191298484802
#  —
#  поднимаешь только —
#  Может на свете
#
#  по моей тебе — и
#  сузьет перешай!
#
#  От поцелуев
#  я в поле резки
#
#  Портит весь имидж
#  теперь их не честь
#
#  Стал тени расцвели.
#  Нету запаха
#
#  не доволен я
#
# Loss: 0.6403826284408569
#  — как нельзя
#  Он в положеньи риз
#  На мини сказал —
#  по склону холма. тебя.
#
#  Вот тебе и май…
#
#  Наверно сбрендил
#  Советский паспорт
#
#  Стал тона из в кончу
#  Зачем ты пришла?
#
#  Выросла весной
#  Паутин
# Loss: 0.6382074272632599
#  —
#  Зачем, dля ветвись самурай
#  все разобрали
#
#  В город крестьянин
#  Проснулся в под столя.
#
#  Как японский бог
#  Вперелочка моя
#
#  По дороге не стоит.
#  Заколевки проснулся
#  с телка скорей! —
#
#  на бере
# Loss: 0.6330963933467865
#  веселом.
#
#  Старый ветерок?
#  Вот тебе и май…
#
#  Зачем ты пришла?
#  запорошело летаю
#  тет голову — там.
#
#  Проверяя скрипт.
#  Да и придет в город белья:
#  «К пивному ларьку!»
#
#  Тихо задремал
#  как японски
# Loss: 0.6390142977237702
#  веселом.
#
#  Прохладный ветер.
#  и с горит сон летней стердая
#  В небе и преплыла.
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Летний отпустили
#  Его там вокруг
#
#  на ложда равше
#  Не то что
# Loss: 0.6428364074230194
#  саду
#  Прошедший так на ветке
#  Ночного света.
#
#  Вот тебе и май!
#  не нужен доктор
#
#  Опять один я
#  На ноге бомжа
#
#  полная врага
#  Разбиты поведний
#  в сортире, тужась.
#
#  Усталый Сегун
#  После полей кусн
# Loss: 0.6376103043556214
#  саду
#  Пропил сапоги.
#
#  Завтрак на воле
#  Зарцас улинок.
#
#  Вот тебе и май!
#  не то что лошадь
#
#  вот леник сказать —
#  мне не помню палел.
#
#  Ворон, погляди,
#  Не то что лошадь, то
#  не спряталась за водк
# Loss: 0.6403027141094207
#  Алеца
#  И полна лица —
#  корова смотрит.
#
#  Прохладный ветер.
#  На скаку. Не поделят
#  На мечто. Тровать
#
#  поменний вечер.
#  На скаку. Не поделят
#  в положеньи риз
#
#  Совсем старый пронить
#  Сторпескает вам
# Loss: 0.6409488117694855
#  —
#  Заботарили двое
#  Зачем ты пришла?
#
#  Верно, в поддалась сон и
#  не последним вастья,
#  Если не стоит.
#
#  Старый ветер
#  Какой как скоро поймать я —
#  тихий свечно. нет
#  На скаку. Не поддать то, саки
#  п
# Loss: 0.6393904614448548
#  такаешь моей воды.
#  малась за ним пришла —
#  От поцелуев.
#
#  Как ворупрай волнует
#  Стоит ли любить?
#
#  Совсем не Байрон.
#  На свете дураком
#
#  По ноский ноге бомт
#  И проснино помню
#
#  Уходи скорей!
#  Есл
# Loss: 0.640560611486435
#  песталась с лаврал
#  В поле вечер пить
#  Прошедший бага,
#
#  От поцелуев.
#  Нет, по ноча вся на воле
#  вот и приплыли.
#
#  Полночь. Manhattan.
#  Гнусно воет страженький снег,
#  А теперь прохладный ветер
#
#  Ми
# Loss: 0.639382517337799
#  такляги
#  Теперь сиче его
#
#  вот и вся любовь
#  Страсти в лужу азасты
#  Страшных другу блонный —
#  опять промешкал
#
#  Желтый Цыплёнок
#  В сейчай дожди.
#
#  В небе такая —
#  тихий стала маходеть,
#  Но прицельн
# Loss: 0.644848108291626
#  веселом.
#
#  После постели мне — Карма
#  Нет, говорез. Вот
#  С гейша моя летом
#  звезда еще глядить.
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли
# Loss: 0.6386008596420288
#  саду
#  Проверяя скрипт.
#
#  На свете сладусь в тихон
#  С леняю глубоков —
#  подводят листья…
#
#  Прорухи жута —
#  Такая он ведь. Тоса
#  Под сакурою старить!»
#
#  Любили его.
#  Называли Володей.
#  А припай сторо
# Loss: 0.6393626701831817
#  —
#  по колено в прибое
#  они приледи —
#  не надо света.
#
#  После постелись
#  Поднял я бычок.
#
#  В сортире тужась,
#  Срезая хлысты.
#
#  Посмотри Ду-Фу,
#  Как слажнет с привешь!
#
#  Старик прял пряжу.
#  Бабка по
# Loss: 0.6383382391929626
#  такаешь мой —
#  После полей была в замерев
#  Как сладко пить на парус,
#  долго не понял
#
#  Когда надо спать
#  Лежата в корен строки
#  Сделал я полевой
#  Шидет проснешься ночь!
#
#  Полночь. Manhattan.
#  Гнусно
# Loss: 0.6361650836467743
#  —
#  поднимаешь только я
#  Свою хокку сырак?
#  Старый пристилось
#
#  Сказал Хачатур прочь
#  Разборка в даль правду
#
#  В положно пьет мно
#  Как море в летний строчит
#  Старый прошел — какие.
#
#  Старый ветерок?
# Loss: 0.6360414862632752
#  давать не стоит,
#  Если не стоит.
#
#  Стал тето за нотко,
#  Поймали вода.
#
#  Мудрая гейша
#  Востнул угрюмо
#
#  Светла ночь по снегу.
#
#  Прохладно пьют,
#  Где садил свеклу
#
#  Не повесенний ветер
#  Старый крич
# Loss: 0.6447952938079834
#  саду
#  Нет места смерти
#
#  Ограм их
#  В согнул с карту
#
#  На ночь травы в ней?
#  Так баба ты, гонсу к стали
#
#  Черепица крыш
#  Челывет ли не вечен…
#
#  Стоит ли любить?
#  Старый кричит:
#
#  В город летать —
#
# Loss: 0.6386997246742249
#  —
#  поднял я бычок.
#
#  Волком вспомнил родной
#  Поняль говорил…
#
#  Открыть в гейше замети.
#  Не поведно простью.
#
#  В мыслях о тебе
#  Изучал правду.
#
#  Стал и что поздно
#  Прохладный ветер.
#
#  В сортире ту
# Loss: 0.6389959394931793
#  Алеца
#
#  В спине любимор.
#  Приходи скорей!
#
#  Прорухи жута —
#  Так тете могить мне?
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Прощай, Токио!
#  Что ведь пришло время
#
#  Митей Маниным
#  Был воздвигнут памят
# Loss: 0.6384842383861542
#  имадили
#  Завесть не отрубишь
#
#  Трещит будильник
#  Станин в гейше не надо
#  Как приходи скорей!
#
#  Весенний дождь.
#
#  Что бы согреться
#  Водкой холодной говорю
#
#  но сейчас ноге лужу.
#  Но к перелетный ку
# Loss: 0.6383525359630585
#  —
#  поздняя осень.
#
#  Прохладно у меня
#  деда порается в утрой
#  Портит весь имидж
#
#  Я в положеньи вижу
#  Чину. Панову бедну
#
#  «Хочу работать!»
#  Но и СПИД сойдет.
#
#  Лето на дворе…
#  Как волон глядится в
# Loss: 0.6362981212139129
#  на самом его краю
#  Добрый пристило
#  по колот ветер
#
#  В зеркало гляжусь:
#  На свете дети осень
#  и на сехон свеку.
#
#  Порножурналы
#  В детстве словной добрал
#  Гная стервять вокруг
#
#  Подла повестно, что
#
# Loss: 0.6372821700572967
#  веселом.
#
#  Проснулся в поту
#  Плохой последний ночью
#  осень с поперхнется
#
#  После постелись в подних помню
#  Нет, не хочется
#
#  В зеркало гляжусь
#  До горит старик ли Дарщивы
#  На ноге бомжа
#
#  полножун
# Loss: 0.6385568714141846
#  пастоль мачно.
#  Весенний денек.
#
#  На свете дети осень
#  и видетелся живаго,
#  Добрый — небольно
#
#  В сад и ни стенного
#  голос цикады
#
#  На мость не стоит ли
#  Смотрит на неё
#
#  уж не осталось
#  не замерз
# Loss: 0.6386503684520721
#  саду
#  Прощайся со мной!
#
#  Стор за водку мне,
#  Не то что лошадь.
#
#  уж не зарывал,
#  Как ты, как приплясь мир я написать:
#  «Коля-то не надо
#
#  Посмотри скорей!
#  Что нельзя смотреть
#
#  Грустно смене.
#
#
# Loss: 0.637493097782135
#  —
#  Зачем трахаться, не стоит,
#  Если не стоит.
#
#  Голос модема!
#  Как волон глядит ли вы
#
#  Все мне едино
#  Хочу и пишу
#
#  но не сливы. Вот и взглядом
#  не стоит либов
#
#  Притавьтесь, что дерево
#  Заявил Х
# Loss: 0.6382352077960968
#  —
#  поднял я бычок.
#
#  Ворон, портих солного
#  Пролетарии…
#
#  Полночь. Manhattan.
#  Гнусно воет следной кусло полизвил
#  На ночь пристревы светлый листьев
#  Как ты на полевой
#  Милая моя!
#
#  Станальсом мерз
# Loss: 0.6334416842460633
#  саду
#  Пропил сапоги.
#
#  Не повестрой!
#  Приснится же такое —
#  Хоть старый пердун.
#
#  «Тель пришла
#  возрадоми в Москву
#  На ноге бомжа
#
#  пропил сапоги
#  теперь и вечно.
#
#  Старый правтра
#
#  От поцелуев.
#
# Loss: 0.6412223041057586
#  веселом.
#
#  Может и в ухо…
#  Веселились, но стать 1000 — ух!
#  Как ты не потом не потом.
#  Сперва сотрес телега
#  под сторожно с нем.
#
#  Все мне едино
#  не помню повесить
#
#  Полночь. Manhattan.
#  Гнусно вое
# Loss: 0.6374678599834442
#  —
#  после наботине, что я
#  Взяли гора на нее
#  давать пришла
#
#  В небе высоком
#  не мог оставить
#
#  Пролетарии
#  в полосаем вокруг
#
#  но было поздно
#  поезд зеленый
#
#  Поднимусь –
#  В страшных пришел.
#
#  В
# Loss: 0.6400701701641083
#  такий вачила
#  И станько под собою
#  Дай лишь понял бакары.
#
#  Не любил Хрущев:
#  Как отрезало глячь нас
#  В согнул на растает?
#
#  От поцелуев.
#  Нельзя в короткий!
#
#  После постелись
#  Поднял я в моркать —
# Loss: 0.638616064786911
#  —
#  после надо все в мир — тросила —
#  как японский бог
#
#  Полночь. Manhattan.
#  Гнусно во все ближе.
#
#  Стал тише воды.
#  От поцелуев.
#
#  Все отсыхает…
#  Какой цикада.
#
#  Вот тебе и май
#  Проделя вижу
#
#  В
# Loss: 0.6428665125370026
#  на поле теперь!
#  под забыл воздветь — той стровать
#  ведь может быть под толчки.
#  Нет, не хочется
#
#  От поцелуев.
#  Нет, не хочется
#
#  Порножурналы
#  Выпью тебе и меня
#  Станином ты пришла?
#  запускал в не
# Loss: 0.6412915360927581
#  напил кувшинстик
#  В старости от ныть.
#  Но и СПИД сойдет.
#
#  Старый крикать мне
#  Только успела —
#  голос цикады
#
#  любимая, ты
#  помнишь, как кричал всю ночь
#
#  Отрывал насоко
#  Прорезал как проснутил
#
#
# Loss: 0.6368677973747253
#  Сегун
#  Под ты расты.
#
#  Сказал Хачатур
#  Какой короткий!
#
#  Полночь лучше в нен…
#
#  Послали на столень,
#  Солнышко, блин, постель.
#  Но утоплись в цвету.
#
#  О, стихи еще день скрипт,
#  в заснеженный больз
# Loss: 0.6355577659606934
#  Алтовы!
#
#  Пропил сапоги
#  Тетется строки.
#
#  Как ли сказана.
#  Я просто на ветке
#
#  Полный идиот
#  Сладко почивал.
#
#  Но он — раздолбай
#  А то не утром уйду
#
#  Полночь моя река
#  Смотреть в пряжу собою
#  С
# Loss: 0.6303967082500458
#  —
#  пора ласкает все тебе и
#  Под тиходее
#
#  пение ет нет, крастывай!
#  Скупят в окно поздно
#  Выросла весной
#
#  Светлый день не помню
#  Полны слезами.
#
#  Сад все леснан.
#  Но суть о видеть, господ!
#
#  Сказ
# Loss: 0.6391559374332428
#  —
#  поднял я ладока.
#
#  Но не устанет
#  Желтые листья…
#
#  Кропил коздрчило.
#  Вот сбадкову столько
#  Ильича додрий завеин
#
#  не получай.
#
#  В мыслях о тебе
#  Как ты мне, странствия старик
#  На стол упала
#
#
# Loss: 0.6383671605587006
#  веселом.
#
#  Старый ветерок.
#  Лето на дворе…
#
#  Стал ты, Мартынов —
#  Хоть старый пердун
#
#  Одиноко мне
#  А каками на дворе…
#
#  Пропил сапоги,
#  Ети и капли мне — Карма
#  Какой короткий!
#
#  От поцелуев.
#  Н
# Loss: 0.6377908062934875
#  Алеца
#
#  В положный по снегу.
#
#  Пролетарии
#  все равно уходит
#
#  Но было поздно
#  простал странский дрогнулись
#  В зеркало гляжусь
#
#  в забить на них —
#  переверный ветер.
#
#  Дом вспомнил родной
#  Перекре
# Loss: 0.6412389612197876
#  —
#  лебединовили
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Совсем старик привычки
#  с фирный ветер!
#
#  Все отсыхает…
#  Наша и с невекре
#
#  Не повесят на поле
#  На носок осталась с листьяв
# Loss: 0.6366016447544098
#  —
#  «Говорит Москва!»
#
#  Сказал Хачатур.
#  Вот скоро уходит
#
#  Любили его!
#  А он привычный привычки.
#  Поникластеет
#
#  После постелись в поделись!»
#  Не склоне гейша
#
#  Порнухи звуки
#  (изображения нет)
#  у
# Loss: 0.6383915674686432
#  —
#  поздняя осень
#
#  Порножурналы —
#  Летняя ночь небольно
#  Измены сладость
#
#  Кукушки наливши!
#  Вот смель. Ветер поднял пыль.
#
#  После набочи, а
#  боть привется светлый ветер
#  Старый прошел — в окно —
#
# Loss: 0.6324611902236938
#  Алеца
#
#  Завлекла гейша
#  Устал я сегодня
#
#  проверяя скрипт,
#  на ноге бомжа
#
#  проверяя скрипт,
#  не поделят кувшинчик
#  В старости он я…
#  Гадит собака
#
#  сновидением
#  виделся мне в темнотом
#  Хрен я в м
# Loss: 0.6386329233646393
#  веселом.
#
#  Старый вечер пишу
#  Под засновал я был перецемнит!
#  На секеем сердит.
#
#  Как японский бог
#  Возразни снега к снег,
#  А все в бамбуки руби
#
#  Проснулся в поту
#  Где дуревый дарь тебе…
#  Как ты м
# Loss: 0.6400154042243957
#  веселом промной.
#
#  Как проснешься жить
#  На завтрак онин
#
#  вот и вся любовь
#  Станет старик поставить
#  Поняль прыгнуть в п***у
#
#  ты в моем сердце
#  стал под стоит лишь
#  На ночь пристреву полем —
#  свет
# Loss: 0.6408718240261078
#  —
#  «Не нужен насущался
#  Не последним саду.
#
#  Проснулся в поту
#  Проснулся в полно
#  С бухарина скорей!
#
#  Как дальше жить мне?
#  Там нас Арами на веткался
#  Сремя меня стира
#  Слезы на полевой
#  Молчана ли
# Loss: 0.6346015095710754
#  веселом.
#
#  Проснулся в поту
#  Проснешлылся верху
#  утром усталось
#
#  на ноге бомжа
#  По моей такой колоны
#  скрипит подина.
#
#  Партии надо
#  Объединиться или
#  Размежевать бим,
#  Что гильотина…
#
#  После пос
# Loss: 0.6421621322631836
#  —
#  поздняя осень!
#
#  Когда надо спать
#  По след виновский во сне.
#
#  То вам не больше сану
#  И такое ворон
#  Ночного света.
#
#  Лето кончилось
#  Пропил сапоги.
#
#  В мыслях о тебе
#  Светлый нас полночь
#
#  Го
# Loss: 0.6389966225624084
#  —
#  ведь прилывая ветер.
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Старый попать на расска
#  От поцелуев.
#  А на самом его краю
#  Дремлет бабочка.
#
#  Промолочи скурень…
#  Вспомнить приятно!
#
#  Прощайся со м
# Loss: 0.6418090915679932
#  Алеца
#
#  Вспомнить приятно!
#  Как дальше жить мне?
#
#  После постелись
#  Понял, амиго?
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Старый крикать мне
#  давать провершенца.
#
#  В небе такая —
# Loss: 0.641896299123764
#  —
#  прошедший там, закрыла.
#  Одевать «мини»
#
#  «Коля-бою в морка
#  В страшных полет.
#
#  Тоском Маримо.
#  Сказана, молков
#
#  Как там Воркута?
#  Вот сбадевал я тараканул
#  Потом закушу писать —
#  Приденько ге
# Loss: 0.6378548467159271
#  —
#  весна на дворе…
#
#  Осень на дворе…
#  Перва саморгало гляжусь
#  До головокруженья
#  Никто не вечен…
#
#  Нет, не хочется
#  Старый ветерок ветер
#  Странно все это!
#
#  Вот тебе и май!
#  не ест в гейше
#
#  Посл
# Loss: 0.6368847072124482
#  пастолевкий строчит…
#
#  Весенний дождь.
#
#  Что бы согреться
#  Водкой холодной ночью.
#  Соловей в ветверил
#  я страстно блюю
#
#  проверяя скрипт,
#  Вечен порядок
#
#  Стал ты, Мартынов —
#  Холод берег с другой
# Loss: 0.6427162647247314
#  веселом.
#
#  Прохладно у меня
#  деда порается в утро…
#  Ветер поднял я пьяный
#  в положеньи риз
#
#  Уж нельзя смотреть
#  С буду камни соланее
#  На склону в тоже —
#  он уйдет босым
#
#  полножунали
#  и самох меня
# Loss: 0.6387205076217651
#  — как затонудорит.
#  совсем не Байрон.
#
#  Дом вспомнил родной
#  Под силина луны…
#
#  Старый правтра
#
#  От поцелуев
#  говорил совесть
#
#  Прибил я жука
#  На ноге бомжа
#
#  не вол подоре.
#
#  Прохладно видеть
#
# Loss: 0.6357583701610565
#  саду
#  Поднимают в портили
#  как любовь, и хамон смоти.
#  Так сладко пришла!"..
#
#  Холодно мне, темноты!
#  А заказала. это дожди.
#  Но заморосил милов
#  Какое листа
#
#  Поставлю Direct
#  И памятник воздвигнув
# Loss: 0.6422271490097046
#  —
#  поднимая светлый дерес
#  любимый во сне
#
#  Не любил член —
#  Как там Воркута?
#
#  он не скримай.
#  Но рассказать хокку
#
#  Стоит ли любить?
#  Нет места смерти
#
#  Облака плывут.
#  Стоит ли любить?
#
#  Весен
# Loss: 0.6369650185108184
#  саду
#  Прошедшие дни
#
#  не доволен я
#  Терзанья духа
#
#  по тим утонка —
#  Мавзолей — светно.
#
#  Как там Воркута?
#  Вот сбадевал я тромбы
#  и выплыла и свет.
#  Но и СПИД сойдет.
#
#  Не повесил на разокла
#  Опя
# Loss: 0.6412556934356689
#  Сегуна спад.
#  Ноги в поле в водки от плакали
#  водкой по сказал покинуя
#  поезд зеленый
#
#  Полнолинка —
#  Вечен порядок.
#
#  Молоды — мыслись,
#  На поле мало мне ность
#  жужжат комары.
#
#  Прохладный ветер
#
# Loss: 0.6368531358242034
#  такие. Но мне
#  ну и вонь была!
#
#  пропил сапоги
#  теперь и вечно.
#
#  Все в сортире, то
#  в положеньи риз
#  Но не устанет.
#
#  теперь их не съесть
#  дождливый гусе
#
#  Порножурналы
#  Выписывать не стоит,
#  Есл
# Loss: 0.6416213309764862
#  веселом.
#
#  Весенний день.
#  Остной проснулся
#
#  Долгий день напролет
#  Под забил сапоги.
#
#  Смотрю на луну.
#  Как там Воркута?
#
#  Матом ластой мой
#  Хоть старый пердун
#
#  От поцелуев.
#  И кости лежат
#  С т
# Loss: 0.6319029343128204
#  —
#  весна на дворе…
#
#  «Прошай, Токио!»
#  стал на друга обветный
#  Гориз. грестьет старил
#
#  В положный по снегу.
#
#  Проснулся в поту
#  Проснулся в полтом
#
#  с утром успела
#  и в голос цикады
#
#  Старый пра
# Loss: 0.6361295354366302
#  веселом.
#
#  Старый вино —
#  По склону в веселовек.
#
#  В зеркало гляжусь
#  До горит собака
#
#  И лететь здорово!
#  не повестрой!
#
#  Приходи скорей!
#  Что ведь я же мальчик…
#
#  Совсем не Байрон.
#  Ночь на исх
# Loss: 0.6380955708026886
#  Сегун спода
#  Не понимал я — — —
#  коромал проплыванья
#  от соловей в саду,
#  Приплыла ночь. Трахать,
#  Мы стал ты, Карма…
#
#  Опять один я
#  Не последним вастья,
#  Если не стоит.
#
#  Прохладно у меня
#  деда по
# Loss: 0.63530397772789
#  —
#  поднимая светлой вечер.
#  На неподвижных ветках
#  С головокружень.
#  Вот тебе и май!
#
#  по дороге не стоит.
#  Не нужны пришла?
#
#  света. по снегу для тебя
#  А нам самурая
#
#  Проверяя скрипт
#
#  проверяя
# Loss: 0.6457494425773621
#  —
#  по во мор собое вред берег веслено
#  Не то что лошадь круби.
#  Стоит или не ветер
#  С головокругом.
#
#  От меня не стоит.
#  Не склоне гейша
#
#  Как там Воркута?
#  Вот сбадевал я дело —
#  Пойти напиться?
#
#
# Loss: 0.6347899413108826
#  —
#  поздняя осень
#
#  Порножурналы —
#  «Не такой уж слушай!»
#
#  Уж сгустилась ночь
#  Не замерзли тучает
#  Стих сладкозвучный.
#
#  Прохладный ветерок.
#  Поникли в шлягчевке
#  Словно колокольевой
#  Первая хокку!
# Loss: 0.6406502759456635
#  песталась солней —
#  сухи. Прочита
#  Правду. Панову перепьет сходить
#  Что я полостья
#
#  Перелетные поддать
#  в заснеженный лес
#
#  Не помню поставьте
#  стал ты, Карма…
#
#  Порнухи звуки
#  (изображения в крес
# Loss: 0.6394948709011078
#  напиться?
#
#  Свежей говорили
#  Компала в октябрат
#  Свою любовь, гетера.
#  Архал тонул на презля
#  милини свет.
#
#  Вот тебе и май!
#  не женьми служась
#
#  вот и вся любовь
#  Стал ты, Марила ухоня
#  Станет ска
# Loss: 0.6409630894660949
#  Сегуна.
#
#  Вишни в поду кончить
#  Сторие в вода.
#
#  Весенний день.
#  Облака плывут.
#
#  Прохладный ветер
#  Старый с короткий ветру
#
#  Опять один я
#  А ты в голой пастоля.
#  На тонких нет уходит.
#  не доволен
# Loss: 0.641601356267929
#  Алецей.
#  теперь и папу
#
#  Дело простое.
#  Не повестрой васти.
#
#  Прохладно и дела
#  голос цикады
#
#  Переменный вечер
#  вот и приплыли.
#
#  Поднимусь лучше
#  Стала так и мир — камень.
#  Воровой строй — на ст
# Loss: 0.6375611984729767
#  саду
#  Прохладно и порается собою
#  Ночного света.
#
#  Плохой пастор Голове…
#  А я саке я…
#
#  Ты причитав в лесу.
#  Какой окти-сурот.
#
#  Молоды — мысли.
#  От взгляда мостямой
#  Помни на цветы мыш.
#
#  На свет
# Loss: 0.6373469471931458
#  такаешь моей мальце
#  соверте… праплыванием вопрос
#  по дороге на свете
#  Полотенза дурес
#  Был в туалете
#
#  Прохладный ветер
#  Старый кричито
#
#  Лишь Сталин не спал:
#  Списки врагов народа
#  проверял, скрип
# Loss: 0.6371904003620148
#  —
#  поздняя осень
#
#  Пойду на дворе…
#  Перва саморгало гляжусь
#  До головокруженья
#  цвета и немали мне
#  деньги я люблю
#
#  Как сладко не пьет тропы
#  Теперь прохладный ветер.
#
#  Иду к правду
#  Одевать «мини
# Loss: 0.6368475484848023
#  Алтовы на светве
#  Страсти в легроткой
#
#  От насекомых
#  Смотрит на неё
#
#  уж не осталось
#  не заметил…
#
#  В зеркало гляжусь:
#  Сотрый мило в колоде
#
#  Полнолуния весь весь Света
#  Нету запаха
#
#  не мог ос
# Loss: 0.6341110837459564
#  —
#  поднял была ты в жином
#  На ночь травы в Сиг
#  Под любовь опавшию в саду
#  Нет места смерти
#
#  Осень скорей!
#  ударили под стеитя.
#
#  Как японский бог
#  Вот свою он.
#
#  от самом или —
#  опять промешкал
#
# Loss: 0.634512197971344
#  Сегун
#  Поднял я бычок.
#
#  Ворон, похородоре
#  остров наша вода.
#  Шумно стало тут…
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Пролетарии
#  в полю он вот виновая
#  как и меня рекребол.
#  Пора поведнов дождь.
#
# Loss: 0.6408361303806305
#  —
#  Изучал «Правду».
#
#  Плача, вспоминал
#  Как уж в море езду лежит
#  стараше в нердон колову.
#
#  Голос модема!
#  Как сладко пить.
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Порножурналы
#  В положный прибыну
# Loss: 0.6349764668941498
#  Сегун
#  Поднял я бычок.
#
#  Ворон с луной. Падал —
#  Хоть старый пердун
#
#  Осень на дворе…
#  Первый вина, ведь
#  Гаданое легко
#
#  на ложит давечи.
#  Сладко почивал.
#
#  Лето кончило-с.
#  Поникли в телаз!
#
#  П
# Loss: 0.6368553757667541
#  веселом.
#
#  Прохладно у ворот!
#  Звезд имена называет
#  Нету догна дне быть?
#  А на самом его краю
#  Дремлет бабочка.
#
#  Промородость ни стать, стихи…
#  Как ты приграла листья
#  В спите всех своих кусны,
#  П
# Loss: 0.6357361495494842
#  саду, как меня ник
#  Смерти след вижу
#
#  в заснет на пить
#  Даже подкову.
#
#  В положный по снегу.
#
#  Приходи скорей!
#  Стоит ли любить?
#
#  Совсем не Байрон.
#  Вот тебе и май…
#
#  От поцелуев.
#  Нет, не хоче
# Loss: 0.6380909645557403
#  веселом.
#
#  Старый правтра
#  Ласточки смело всех меня
#  поезд зеленый
#
#  Посмотри Ду-Фу,
#  Как сложал пишу
#
#  Проще жизнь на нее
#  Плакали дети…
#
#  Любимый во сне
#  Торон с работа.
#
#  Парлила она
#  Лето на
# Loss: 0.6359380316734314
#  веселом.
#
#  Местечки свет
#  мертво далеко тебя.
#
#  В старости обстреик.
#  Баба кушал к кончал:
#  С головокружень.
#  В летней сокруг, ты — как я
#  Голос цикады
#
#  по моем сердце
#  нет места летит кувшин
#  Оде
# Loss: 0.6423439705371856
#  саду
#  Нет места смерти
#
#  С привили на неё
#  то отдается в ночи,
#  то в моем сердце
#
#  После постелись
#  Понял, амиго?
#
#  Когда надо спать
#  Головил к правозарином.
#  Как быстро почему так?
#  На своей шивыч
# Loss: 0.6373186659812927
#  такаешь моей воды
#  И под снего постель.
#  Сотоей вокруг?
#
#  чуть остался жив.
#  В небе такая —
#
#  прость поцелуев.
#  На силкоров нет —
#  Он все равно уходит
#  Жестокий талант
#
#  Порножурналы
#  Выпей горилки
# Loss: 0.6409551191329956
#  такий вачинал
#  В новые свыходеть
#
#  Прохладный ветер
#  Старый с кончил.
#
#  То скоро успела
#  Осенний вечер.
#
#  Весенний день.
#  Остались круги
#
#  дырявый парус
#  беззастенчиво
#
#  Посмотри Ду-Фу,
#  Как слов
# Loss: 0.6392234981060028
#  стал ты, Мойша!
#  Нет, по буду тебе одни.
#
#  Как волопом
#  На нее вернулся
#
#  На свете сладусь ветках
#  И склону в вешина
#
#  Черепица крыш
#  Словно придет старик
#  После полей посетро
#  Первая хокку!
#
#  Вес
# Loss: 0.6339563572406769
#  веселом земле
#  голос цикады
#
#  первая хокку
#  Порножурналы
#
#  полная, строк трасал
#  ох, Махмуд-ухан
#
#  Голова броман.
#  На ноге бомжа
#
#  праздник у друга
#  Свое сидит пленен летно
#  Стоит ли любить?
#
#  Де
# Loss: 0.6405154883861541
#  веселом подуть только
#  Измыром бы они…
#
#  Так я и жить все мерте?
#  Совсем не Байрон.
#
#  Вот тебе и май…
#
#  Заплатила дань
#  Завтрак на воле
#
#  Порножурналы
#  В положный могильный биром
#  опять промешкал
#
# Loss: 0.6337710678577423
#  Таковой столицев сто пользу
#  Выпей горилки
#
#  Не получилось
#  Проснулся в поле.
#
#  Прохладный ветерок.
#  Просыпаешь ветер.
#
#  Все вночи, что ушла
#  Зачем — привычным
#
#  Прохладный ветер.
#  Голос модема!
#
# Loss: 0.6412448978424072
#  веселом.
#
#  Пролетарии
#  все равно и не стоит,
#  Если не стоит.
#
#  Стал под ним – и что призна.
#  Грабать в голове,
#
#  под там он отрособ.
#  Посмотри скорей
#
#  Вечен порядок
#  В небе любовь идет,
#  А больше
# Loss: 0.6371078968048096
#  веселом.
#
#  Милая моя!
#  Ты пригал, промана
#
#  Подла тебя стерным
#  У нас и к себе пей засыби
#  Нет, не устанет
#
#  Пролетарии
#  все равно уходит
#
#  Завлекла гейша
#  Устал я сегодня —
#
#  Прошедшие дни
#  Всяд
# Loss: 0.6431184458732605
#  веселом.
#
#  Весенний дождь.
#  Вот страстию ванились
#
#  вот лишь понюхать…
#  Дом вспомнил родной
#
#  От самогонья —
#  теперь опевник в потом.
#  Поднимают ли короткий!
#  Понин весна вредных мне
#  опять промешк
# Loss: 0.6360791492462158
#  —
#  весна на дворе…
#
#  Осень на дворе…
#  Полночь. Там, простой но
#  За потом усну
#
#  Вите мия в пряму лебят,
#  Принимали зачем
#
#  понял амиго,
#  что там интарет
#
#  правду изучил
#  Видением в полночь.
#
#  В с
# Loss: 0.6337104105949402
#  напиться?
#
#  Островки по тебе
#  Лето на дворе…
#
#  Теперь сижу вот —
#  Зачем, для беззаботно
#  Свежей говорили
#
#  Смотрит на неё
#  Облака плывут.
#
#  Нету запаха.
#  Увы, не сядет пчела
#  На этот цветок
#
#  В п
# Loss: 0.6390485417842865
#  —
#  прошедший там вокруг
#
#  Не то утром уйду
#  из же на болите
#  совсем не Байрон.
#
#  Дом вспомнил родной
#  уйден ночь то отраздний гнезд
#  что было легкой ветра
#  Стал ты из нас — под утро
#  С гетерой потид
# Loss: 0.6377875089645386
#  веселом.
#
#  Прохладный ветер.
#  — А старый лизлек, то
#  в положеньи риз
#
#  Усталый Сегун
#  После полей буду Вачив
#  Жиртесь как японский бог
#  И заботачило время
#  голос цикады
#
#  пенис, то ушла
#  Небеса ты
# Loss: 0.6378304481506347
#  песталась с листьявай.
#  Придит на самом его краю
#  Добрый пристило
#  Разбитое под старый —
#  Видений глюки?
#
#  Матом вокруг цветок
#  Прошедшие двое — мурини крастить
#  в садил смотреносок.
#
#  Как неугоморо
# Loss: 0.6431354200839996
#  —
#  после надо в припонсков
#  Поднимусь сограны
#  Свежа вокре на поле
#  Выросла весной
#
#  Толком не отрова
#  Порножурналы
#
#  Не помню, друзья!
#  И собрать все влеза…
#
#  Два су ты должна
#  Мне неизвестно.
#
#
# Loss: 0.6358504617214202
#  такаешь мой —
#  Мент прочью стиховина
#  В небе и преннимают.
#  Лето на дворе…
#
#  Старик прял пряжу.
#  Бабка поднила тука
#  ты в моем сердце
#
#  Лето на дворе…
#  Полный идиот
#
#  Когда надо спать
#  Лежата в мор
# Loss: 0.6371650147438049
#  —
#  Так японский бог
#
#  Порножурналы
#  В детстве словно туча стихи
#  Парус в полночь.
#
#  Ворон, поймается
#  В старом прижится
#
#  Иди ты на пользу
#  В ловость не стоит?
#
#  Глянул год утро
#  Смотреть в прошел
# Loss: 0.6387787926197052
#  —
#  Зачем, для чего
#
#  под забыл я — Мойша.
#  Лишь и сидит и играя —
#  Осенний вечер.
#
#  В зеркало гляжусь
#  Доктор живаго?
#
#  что же летом
#  В небе нас любить —
#  Веселились, но стать 1000 — ух!
#  Как ты по
# Loss: 0.6369676685333252
#  Сегуна?
#  Теперь сижу вот —
#  И остался стран?
#
#  Совсем не Байрон.
#  Вот тебе и май…
#
#  Лето на дворе…
#  Как волон глядится в зеркало
#  я засыпал Карма…
#
#  Скучно тут в Штатах.
#  И напиться услышиной
#  Выро
# Loss: 0.637614541053772
#  веселом похоронились
#  После наворонки капли
#  Разновидок идет холода,
#  сновидением
#
#  Пропил сапоги
#  теперь я непридется
#  Мне не придет наш Флиткул
#  На ноге бомжа
#
#  не подарит Дубею
#  Старый прошел — н
# Loss: 0.6363036119937897
#  —
#  после надом услышки.
#
#  В мыслях о тебе
#  Изучал правду.
#
#  Стал тето закого стеть.
#  Нет, с тихой старик
#
#  Ухо ласкает
#  И проснино под окно
#  Портит весь имидж
#
#  утоплюсь в море!
#  Станет собака…
#
#
# Loss: 0.6402177786827088
#  напить он не спрасвел
#  нет в поле от плевал
#  Просыпается строк,
#  В небе такая луна,
#  Как за спили мне слома
#  Смерти след вижу
#
#  подель не успела
#  облака плачут.
#
#  Любили его!
#  А он привычный привычк
# Loss: 0.6401805210113526
#  —
#  поздняя осень.
#
#  Прохладно у меня
#  деда полменей!
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Старый крикать мне
#  деньги я люблю
#
#  В положно пьет мне
#  Только успела —
#  морзу больно и
#
#  Прочевать пр
# Loss: 0.6381395089626313
#  —
#  теперь прохладный ветер.
#
#  Долгий день напролет
#  Поразонтов в корез
#
#  На берег в морковку
#  Проверяя скрипт.
#
#  На свете сладусь в тихон
#  С новый листон моя в саду
#  Нет — не стоит лишь —
#  Сказал Х
# Loss: 0.6380885791778564
#  назад видно,
#  Как старая летом
#
#  скорей СПойку, беская
#  На завтрак они на мый травы,
#  А беже написать —
#  А он… в октябре…
#
#  Рюмочек на волю.
#  Стоит ли любить?
#
#  От поцелуев…
#  Кукушка козлов
#
#  Совс
# Loss: 0.6341485810279847
#  — как затонудорит.
#  с папу, вони летом
#  Смотрю на рассвете
#  Куда ж нам плыть-то?..»
#
#  Треснула люстра
#  Как сладко не отрубишь
#
#  Стал тише воды.
#  Наша и одетал
#  У ворон в поле —
#  теперь их не честь
#
# Loss: 0.6339320719242096
#  саду
#  Проснулся в поле.
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  После поседенье
#  проверяя скрипт
#
#  Себя наслаждать
#  Не поздняя осень.
#
#  Прохладно пьет мне
#  день не отдадим,
#
#  Уходи скорей!
#  Привуч
# Loss: 0.6385942721366882
#  имахает траве.
#  Проснулся ночью.
#
#  Я там время словно
#  Словно дерево Басе
#  Поймали вода.
#
#  Голос модема
#  В страшных пришел.
#
#  Старик прилитос
#  Выписом захотом.
#
#  В моем сердце
#
#  Прощайся со мной!
# Loss: 0.6354835879802704
#  —
#  не такой уж скоро
#  проверяя скрипт
#
#  Свежей говорили
#  исчасстены в карты
#
#  От поцелуев…
#  Крестьянский день ты,
#  Если тут лежит
#
#  Свежей гостерь
#  Своей пастор Хрупей
#
#  Порножурналы
#  Выпью тебе и
# Loss: 0.6375215327739716
#  такие. Но мне
#  дарцалист обверный —
#  Вот смель. Ветер поднял пыль.
#
#  Сколько жить мне слушай!!!
#  Одиноко в горы.
#
#  Вите Ванину
#  Прошедший мине.
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  После постели
# Loss: 0.6307496154308319
#  —
#  ведь могли наскала
#
#  Глаза, молст он —
#  Под сакурою старить!» —
#  Голос живоготой вечером
#  вот и приплыли.
#
#  Полночь. Manhattan.
#  Гнусно воет следной кусло луну,
#  Был в вечером согрот.
#  Зима на дв
# Loss: 0.6395262575149536
#  веселом.
#
#  Проросил уйде…
#  Подная в ночи.
#
#  Старикан Мухин
#  Глядит на ветке
#
#  В спилиями самох хоть
#  Веселили стать.
#
#  Все в рот на столен.
#  А там, ты — как я…
#
#  Совсем не Байрон.
#  Вот тебе и май
# Loss: 0.6368725025653839
#  Сегун
#  Поднял я бычок.
#
#  Как ворон бамбушка.
#  На скрыть отроше хокку
#
#  Мой бедный зайчик
#  Все в моем сердце
#
#  Зачем ты пришла?
#  запорошело летаю
#  День патриарха
#
#  Свежей говорили
#  Разных заката ни
# Loss: 0.6369786536693574
#  Сегуна.
#  В странно вижка костер.
#  Старый вечером
#
#  на берегах Моганить
#  Лето на дворе…
#
#  Митей Маниным
#  Был воздвигнут проплыла,
#  Веселился и водке
#  Пропал под утро
#
#  Попала в колес0
#  Какая дрянь,
# Loss: 0.6366519606113434
#  — как затонудорит.
#  с тервые простое.
#  но было поздно
#
#  Веселье кругом.
#  Лето на дворе…
#
#  Как уже веда —
#  Плача, дутеть не уроник…
#  Начнется светлый день ты
#  Вспомнить приятно!
#
#  праздник у друга
#
# Loss: 0.643876953125
#  Себу тебя.
#
#  Вечен порядок
#  В небе такая луна,
#  Кто словно проснется
#
#  Полночь могнулся
#  Привычный понял
#  Ночного света.
#
#  Вечен порядок
#  В небе любовь и на воле
#  Злою бедный ветер!
#  Пойдем перегом
# Loss: 0.6446023142337799
#  веселом.
#
#  Может и в ухо…
#  Вот скоро попробела —
#
#  Прощайся со мной!
#  На носок он не вдруг весьта в протел
#  ночь почистое полбер
#
#  «Кама скорей на ветку!
#  Воскрик не стоит либов
#  Проснулся в поле.
#
# Loss: 0.6421404469013214
#  —
#  весна на дворе…
#
#  Осень на дворе…
#  Перва саморгало гляжусь
#  До головокруженья
#  Никто не вечен…
#
#  Уходи скорей!
#  в тень паливать я тебе —
#  На склоне гейша
#
#  Иди в Мавзолей
#  И скоро уходит вина
#  П
# Loss: 0.6388250720500946
#  на самом его краю
#  Добрый — не больно я
#  упала он люмпыл на пролет
#  Уж спустилась ночь
#
#  Cидим в темноте.
#  Зачем плача, вспоминает
#  Стоит ли любить?
#
#  Тоже мне еще
#  Раздолбай выпил
#
#  В мыслях о теб
# Loss: 0.6354093027114868
#  Сегуна!
#
#  По в небе так, слушка.
#  Да и сказала хокку
#  А это другой
#
#  От поцелуев
#  я в поле он воды.
#
#  Прохладно видеть,
#  Проверяя скрипт.
#
#  Бесполезной травье
#  стал на рукой лес
#  Ползи лишь мне не
# Loss: 0.6347295475006104
#  саду
#  Пропил сапоги.
#
#  Нет, не хочется
#  Спать бы обнаны
#  Гора Арарат ведь пришла
#  Осенний вечер.
#
#  Посвед скоро постель.
#  На самом интереснал
#  Какое свалил на крыше
#  Засулит — новый вечером
#  времене
# Loss: 0.6353084290027619
#  веселом.
#
#  Проснулся в поту
#  Проснулся в поле.
#
#  Порнухи звуки
#  (изображения в крестьянин
#  С гетерой стренить в герва
#
#  Стал ты, Марии у колоде…
#  А может в рот на словно
#  Выросла весной
#
#  Стал тет
# Loss: 0.640570639371872
#  —
#  поднял я была так ущер
#  У нас тала ты на полбег
#  Видель нас — свой хокку
#
#  потому рассидется,
#  Чтобы согреться
#
#  праздник у друга
#  Свое старый крики.
#
# ...
#  на ноге бомжа
#
#  не мо
# Loss: 0.6395911693572998
#  пастоль мачно.
#  Все отсыхает…
#
#  Выросла весной
#  Становлюсь старше?
#
#  Плача, вспоминал…
#  Зарплату недавнюю
#  Станик в саду.
#
#  Вот тебе и май!
#  не заметился
#  не то что лошадь, то
#  не стоит либе…
#
#  На
# Loss: 0.6415409636497498
#  напиться?
#
#  Свежею кто не придет
#  Нет места смерти
#
#  Осень скорей! — свыходо
#  Смотрю на луну.
#
#  дед из-под репки
#  не последний друзет
#
#  В добросил в подни
#  или одет молсто.
#
#  Лето на дворе…
#  Полн
# Loss: 0.6425052988529205
#  такла в сортире,
#  Есть поспоет в окно.
#  и раздом рванеть?
#
#  Мой бедный зайчик
#  Все в себе отпрук
#
#  Уходи скорей!
#  по глужуская вакат
#  Разве ж это жизнь?
#
#  Когда надо спать
#  С безали дождя.
#
#  Митей
# Loss: 0.6359511768817901
#  такаешь мой —
#  Заявил Хрущев.
#
#  Прохладный короткий!
#  Не бойся, не съем
#
#  Завтра — на волю.
#  Сто перебрал — тух старик
#  Был в поле открала
#
#  Грустно способна
#  Не повестрой васть
#
#  сила на него
#  Пр
# Loss: 0.6379921078681946
#  саду
#  Не был корей! —
#
#  но утром уйду
#  из дворца самурая
#  в заснеженный лес
#
#  На ветках стороны!
#  Зарплату и мой.
#
#  В мыслях о тебе
#  Изучал правду.
#
#  Слог в эту строку
#  стал подробото,
#
#  Партии н
# Loss: 0.6391248655319214
#  —
#  после надом услышите
#  дед из-под репки
#
#  не доволен я
#  Не повестрой васть
#
#  но не стоит либы,
#  Нет, не возмож. Но простой
#
#  Как за водки в тихонько —
#  Все мне напеда.
#
#  Стоит ли любить?
#  Старый
# Loss: 0.644324607849121
#  такие. Но мне
#  читали с женой
#
#  Стал тето закого стете
#  Станин не спал.
#
#  Дерево – на слоность
#  на ложках, ли любить?
#  На ноге бомжа
#
#  но утром уйду
#  из дворца самурая
#  в заснеженный лес
#
#  Я встре
# Loss: 0.6385857880115509
#  —
#  весна на дворе…
#
#  Осень на дворе…
#  Перва саморгало гляжусь
#  До головокруженья
#  На ночь пристревы светлый листьев —
#  ведь так приходи скорей!
#  Стоит ли любить?
#
#  Совсем не Байрон.
#  Ночь на исходе.
# Loss: 0.6374997448921204
#  саду
#  Прошедший так ну и ветка
#  На скаку. Не подорен.
#  Раздался выстрел
#  Все оботели в поле.
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Стал тето стало
#  облака плачут
#
#  Иду к станы
#  Х
# Loss: 0.6419898808002472
#  —
#  поздняя осень.
#
#  Маленький Мойша
#  Потому тебя!
#
#  Что бы согреться
#  Водкой холодной ночью.
#  Соловьем у повезли
#  Но было поздно
#
#  Разошлись круги…
#  Мячик в реке утонул
#  Завтра — деревню кускал
#  чи
# Loss: 0.6420599865913391
#  —
#  лебедя свежем мороне
#  Поездом! Так их!
#
#  Хоть старый пердун,
#  Не любил шляпом
#
#  весна на дворе…
#  Как волон глядит луна.
#
#  В небе такая луна,
#  Словно дерево спилено под ним
#  из ущель на неё
#
#  По
# Loss: 0.6408299493789673
#  —
#  по напостили с утра
#  Станик в шальцу грустир!
#
#  Пропил сапоги
#  теперь и вечно.
#
#  Старый правтра
#
#  Стоит ли любить?
#  Старый кричит:
#
#  Грустно смотрю, как
#  Разбудите поляну
#  Деда мороза ты
#  по но
# Loss: 0.6388737165927887
#  Сегун
#  Попала в к0лесо…
#  Поздняя осень.
#
#  Прохладный ветер.
#  менял я встреть, Мойша
#  По след весна не отрубишь
#
#  Старый вечер.
#  Не склоне гейша
#
#  Порножурналы —
#  Летняя расцвели.
#  утоплюсь в море.
#
# Loss: 0.6348721039295196
#  веселом.
#
#  Лето кончило-с.
#  Поникли в темноте —
#  что улыбнет с привешь
#  И полна смотрит.
#
#  Прохладно у меня
#  деда полмел и согреть «Сайнул
#  Какой короткий!
#
#  Сугробы вокруг,
#  Веселился вспоминал…
#
# Loss: 0.6392735695838928
#  —
#  поздняя осень
#
#  Совсем не Байрон.
#  На свете сладусь и
#  Прошлось кабетка
#
#  по друга в толком
#  Мару прости запатут.
#
#  Вот была мог весленич.
#  Нету запаха.
#
#  «Говорит Москва!»
#  Проснулся ночи.
#
#
# Loss: 0.641088238954544
#  Сегун
#  Поднял я бычок.
#
#  В сортире тужась,
#  Скрылась в туалете
#
#  Когда надо спать
#  Лежат писам разошлись
#  Понял, амиго?
#
#  Станадесять? —
#  под стоит или теперь
#  Разве ж это жизнь?
#
#  Как японский бо
# Loss: 0.6426120805740356
#  —
#  поднял я бычок.
#
#  Что бы согреться
#  Видением в полночь,
#  вот и вся бы лизу
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  От поцелуев.
#  Нет, не хочется
#
#  Порнухи звуки
#  (изображения в
# Loss: 0.6347623026371002
#  —
#  ведь прилывая в поту
#  Все отсыхает…
#
#  Полночь. Manhattan.
#  Гнусно воет слез.
#
#  Не помню поставьте
#  прошедшие дни
#
#  не поднимая!
#  Вот тебе и май…
#
#  Лето на дворе…
#  Как волопом зеленит.
#  я — не у
# Loss: 0.6386730861663819
#  веселом.
#
#  Местечко Сага.
#  Могилы много бесну
#  Проснулся в полно
#  В положала такает
#  когда доставал круги
#
#  Не такой уж! Он… —
#  под засновай грезда.
#
#  Вот тебе и май!
#  не доволен я
#
#  Никто не вече
# Loss: 0.6371849513053894
#  пастоль мачно.
#  Все отсыхает…
#
#  Выросла весной
#  Помолного без прошел
#  Не поперхнется
#
#  Проснулся в поту
#  Где дуревенько всё украл…
#  Как водку мне помню
#
#  тихо скрипит гондна
#  Видь обака кричит
#
#  У
# Loss: 0.6394681584835052
#  веселом.
#
#  Может и в ухо…
#  Веселились, не спит
#  На ноге бомжа
#
#  хотя бы взгляни!
#  На ноге бомжа
#
#  проверяя скрипт,
#  на берегах Ленин —
#  стал на крыше
#
#  Островки росто
#  В зеркало гляжусь
#
#  в засне
# Loss: 0.6382107818126679
#  Сегун
#  Потому последний бак:
#  «Довся жив нар горном
#  Облака плывут.
#
#  Колокол смолк вдалеке,
#  Не повестрой вачивал.
#  Разве ж это жизнь?
#
#  Когда надо спать
#  С гейше заспал насак.
#  Так и винные места
#
# Loss: 0.6335485708713532
#  пастоль мачно.
#  Все в бабку.
#
#  Порножурналы
#  Выписывать привычки.
#
#  Прощай, Токио!
#  Что жду и и на Барлон
#  Будто это он не спросил:
#  Понял, амиго?
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  В старости
# Loss: 0.6366132879257203
#  —
#  поднимая светлой ветвиский
#  От поцелуев…
#
#  Непривучи в шуть на
#  Свежей писало будить
#
#  Полночь моя расска
#  Этот не больше
#  Завтра — деревне — нигом
#  Подури Когда надо —
#  Теперь сижу вот и в ладок
# Loss: 0.63859983086586
#  пастоль мачно.
#  Весенний денек.
#
#  Ворон, похородоре
#  осторо ухожу
#  а выпил как пришла
#
#  Голос модема!
#  Заротец весим не помню
#  Прошедшие дверит.
#
#  Мент просить венег
#  Пойти напиться?
#
#  Себя услажд
# Loss: 0.6413996553421021
#  —
#  поднял я бычок.
#
#  Ворон, поймаешь —
#  На непримортели к ней
#  их не придет…
#
#  Ты не придет
#  На ночь пристрело гетерех —
#  Не помню поставьте.
#
#  Как своей кончилось.
#  Лето на дворе…
#
#  Старый правтр
# Loss: 0.6351766395568847
#  Сегун
#  Под сакурою
#
#  Порножурналы
#  В положно пьяник
#  молодой господин нашь
#  из писана на деревня
#  Старый прошел — на столре
#  Свою любовь, гейша
#  Устал я сегодня —
#  хожу босиком
#
#  Стих сладкозвучный.
# Loss: 0.642496155500412
#  Сегун
#  Под сакурою
#
#  Порножурналы
#  В детстве читали с тобой
#  В сторовый голову
#
#  Как за сто первый хокку
#  Какое листа
#
#  Посмотри Ду-Фу,
#  Как сказывали тужась,
#  Солнее жизнь луна,
#  Как старая листвы
# Loss: 0.6395373284816742
#  веселом.
#
#  Мерзанья на столе.
#  Посмотри скорей
#
#  слухи: микадо
#  задумал харакири
#  вот так праздничный день —
#  недопроверил
#
#  «Прошай, Токио!»
#  стал на рассвете
#
#  В спит на неё
#  Облака плывут.
#
#  в
# Loss: 0.6354602873325348
#  —
#  подводят твой свету
#  Переносную.
#
#  Добрый пастор Шлагг
#  Плакали дети…
#
#  Любили его!
#  А он лежа в небе — ветках.
#  На скаку. Не то что лоша —
#  голос цикады
#
#  Перенаю тексРому?
#  меня скорей ничего
#
# Loss: 0.6426729166507721
#  на самом его краю
#  Добрый пастор Шлагг
#
#  Пролетарии
#  все ли выпьюсь!
#
#  Стор за водку мне — света
#  Но поздняя осень
#
#  Ты помнишь «Сайгон»?
#  Брал «два маленьких крича,
#  Первая хокку!
#
#  После постели
# Loss: 0.6413780796527863
#  Сегуна спад
#  не получать вечер.
#
#  Как же это мы?
#  в глубокаю —
#
#  Плакали дети…
#  в моем сердце
#
#  Пролетарии
#  в положно поленом
#  Не была написана
#  Партии надо
#
#  Приходи скорей!
#  Неприятся светлой ве
# Loss: 0.6425373387336731
#  —
#  поздняя осень
#
#  Порножурналы
#  В положный ковыль —
#  Давай вечером
#
#  все мертво, уйди
#  или нет, нет, не вечер.
#
#  Вот тебе и май —
#  Хревал на меня.
#
#  Веселье кругом.
#  Вот холодной ночь на время
#  П
# Loss: 0.6359805881977081
#  —
#  ведь прилывая любил —
#  по колено в прибое
#  подоре поздно.
#
#  Весенний дождь.
#
#  В зеркало гляжусь
#  До головокруженья
#  На этот цветок
#
#  В терминые висти
#  На ум приходят дождь
#
#  Как дальше жить мне
# Loss: 0.6362157869338989
#  —
#  поднял я бычок.
#
#  В страшно тучает.
#  Потрохота осенними
#  прибоей вечером
#
#  Дерево — стал частор.
#  Стор за стерлила хокку
#
#  Разошлись круги…
#  Лето кончило-с.
#
#  Как ворупрай берка,
#  пошел вон ско
# Loss: 0.6389369893074036
#  саду
#  Пропил сапоги.
#
#  Проснулся в поту
#  Ельцин — всю ночь напролет
#  То Кох, то Чубайс…
#
#  Играет в Тетрис
#  Как сладко пришла гейша
#
#  Иди в Мавзолей
#  И просто поясна?
#
#  Все винели гавей
#  Вдруг все
# Loss: 0.6377301025390625
#  саду
#  Проснулся в поле.
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Весенний день.
#  Но судья не стоит.
#
#  Проснулся в поту
#  Плохой последний ночью
#
# Loss: 0.6380740487575531
#  веселом.
#
#  Старый вино, друг
#  в тишине в лесу.
#
#  Ночь на исходе.
#  Помер дураком.
#
#  Пойду на него
#  Так там согнул бамбук, то
#  в положеньи риз
#
#  Совсем не Байрон
#  моем сердце
#
#  полная луна.
#  Да и п
# Loss: 0.6418106961250305
#  —
#  «Дячется не успеть ты на
#  Сидим в темноте —
#  член в поле отдалась —
#  Так ты на призомлю
#
#  Сколько жить мне?
#  Август кончался
#
#  слуха микадо
#  не то что так воровить
#  Лежит не спится
#
#  Жирик говор
# Loss: 0.6384352207183838
#  —
#  ведь прилывая вернись!
#
#  Стал ты, Мартынов —
#  Холод, нету уж —
#  А есть только ты
#
#  Стал ты, Мартынов,
#  с ленин могили он…
#
#  Проверяя скрипт.
#  По стоит лишь потом.
#  Толкоми постал.
#
#  Старый вете
# Loss: 0.6410410690307617
#  веселом.
#
#  Может и в ухо…
#  Вот скоро последний глядит
#  На ноге бомжа
#
#  но утром уйду
#  из же на свете
#
#  положен и в поле.
#
#  Старик прял пряжу.
#  Бабка порой полем вишней дней
#  Под сакурою старить!»
#
# Loss: 0.637976679801941
#  —
#  поднял была ты в жином
#  Нет, не хочется…
#
#  Порножурналы
#  В поле вечер пишу
#  Под сакурою
#
#  Порножурналы
#  В положала высять
#  И уж в Мекку?
#
#  Все отсыхает…
#  Пойти напиться?
#
#  Себя услаждать.
#  Долг
# Loss: 0.6356187081336975
#  стал ты, Мойша!
#  Нет, по ноча в саду.
#
#  Плохой пастор Грудок,
#  А ты в гругом усну
#
#  Как японский бог
#  Впревидое вине.
#
#  В сортире тужась,
#  Сказал Хакамадом
#  Поднимают в подельют?
#  На поле ветер.
#
#
# Loss: 0.6429357588291168
#  —
#  посмотри скорей!
#
#  Старый пруд.
#
#  Ворон, погляди голове
#  Не мог оставить
#
#  Завтра — на волю.
#  Столкнулся в море —
#  словно короткий старая!
#  не забирит Сегуна
#  Не бойся, не съем
#
#  Весь вечер пиш
# Loss: 0.6372055423259735
#  такляги
#  Тушь пононеский.
#
#  Проснулся в поле.
#
#  На свете сладусь вода.
#  Лучше бы мне тебя
#  Первая хокку!
#
#  В небе надо любимы
#  Разборка в небе так я!
#
#  На проснулся вдруг веслено
#  Завтрак на воле
#
# Loss: 0.6343715584278107
#  — как звездик. Додомился.
#  Отрас саморгали бля
#  Нет весна не надо
#
#  Поднимусь лучше
#  Станет на стол кусты.
#
#  Что глупости в темнот!
#  Нет уж одал — пришла
#  я вердил в темноте
#
#  по моей побежал.
#  Ей
# Loss: 0.6412905323505401
#  —
#  Так японский бог
#
#  полная врагом
#  Своей шела написает
#  На стол упала
#
#  прыгаю в окно.
#  от водки он не знают
#  Потому сакэ
#
#  По поля игрой строки
#  На скаку. Не отдомой!»
#  Вспомнить приятно!
#
#  Как
# Loss: 0.6381470239162446
#  напиться?
#
#  Осень скорей!
#  Что за чудо оден.
#
#  Ворон, похородоре
#  Нету дождя.
#
#  Хочу женшину!
#  Что за чудо кукушки.
#
#  В доме такает
#  и не бойся, не съем
#  По стоит лишь пони коне
#  Поездом! Так их!
#
# Loss: 0.6360792016983032
#  —
#  Какая промешкал
#  примчался верхом в Москву
#  На толкнее не стоит.
#  Не скрыть истину.
#
#  Проснулся в поту
#  Ета как грому такает
#  мучал правду.
#
#  Пойти напиться?
#  и поле моем сердце
#  стал под сакуры
#
# Loss: 0.642884007692337
#  —
#  меня все растая
#  Где садил свеклу
#
#  Поставлю Direct
#  И проснулся вдруг.
#
#  Вот привется, не съем»
#  Выросла весной
#
#  Старый ветерок?
#  Стоит ли любить?
#
#  Голос модема!
#  Как сладко пить.
#
#  Старый
# Loss: 0.6419062948226929
#  Сегун
#  Под сакурое лето.
#  Вот холодной ночь по сто я
#  Стордехник скулит…
#
#  Пропил сапоги
#  Там не придет на полан
#  ветер вода в ладошку
#  по тебе не устанет
#
#  Приходи скорей!
#  Стоит ли любить?
#
#  Совс
# Loss: 0.6385079562664032
#  —
#  Зачем, dля чего
#
#  но утром уйду
#  из дворца самурая
#  в заснеженный лес
#
#  остолетой
#
#  Видение в саду
#  расстели сказать —
#  по напиться услыла
#
#  На поле холодной гнезд
#  теперь опеннимая —
#
#  на лож
# Loss: 0.6426229584217071
#  имах спасиц.
#  То вы уж скоро.
#
#  Приходи скорей!
#  Что нельзя смотреть
#
#  Cидим в темноте.
#  За нею помню, ближи.
#  Может и в ухо…
#
#  Вот тебе и май!
#  не за спасину, комары.
#  зарись прошел пивая – и вижу
# Loss: 0.6372142505645751
#  Алтовы навечед
#
#  сила вновьем я, —
#  То скоро у волней
#
#  Пролетарии
#  все равно и мейне.
#
#  Все отсыхает…
#  Поймай ласам.
#
#  Прохладный ветерок.
#  На свете дети осень
#  и видеть здеревать блядь
#  От поцел
# Loss: 0.6359597277641297
#  гений. Темно время
#  Страсти надом усну
#
#  В небе такие.
#
#  Любили его!
#  А он кустов между —
#  Не был красив. Вот и в луже
#  От стоит не смышки
#
#  В сад и чтеньем —
#  Хоть старый пердун
#
#  Одиноко мне
#  Се
# Loss: 0.6435513210296631
#  Сегун
#  Поднял я бычок.
#
#  Как ворон больно помне
#  прили гораженеве.
#
#  Вечен порядок
#  В небе и прекрасна
#  и не найдесь как я — Мойша.
#
#  Ворон с другими
#  проверяя скрипт.
#
#  Видений глюки?
#  Хрен или р
# Loss: 0.6404084336757659
#  — как не смотри
#  В небе высоком.
#
#  Ветер поднял пыль.
#  Подной привязали
#
#  В конза на столе.
#  Как ты под стоит лишь —
#  Вечен порядок.
#
#  Вот тебе и май…
#  Зачем они тебе —
#  Голос кукушки.
#
#  Вот тебе
# Loss: 0.6398742711544037
#  веселом.
#
#  Проснулся в поту
#  Где дуревый нас трова
#  Лето на дворе.
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Старый крикать холод
#  не с бухарина
#
#  Даже пришла!
#  бросил я камень..
#
#  Сочинял хокку
#  На
# Loss: 0.6348691272735596
#  как грома наподва.
#  От поцелуев.
#
#  На свете дети осень
#  И Баранают в начало
#
#  Что глупости, не —
#  А есть три года открыл
#  Не повестрой васть
#
#  но не стоит лишь —
#  Стихи в голове,
#
#  поздняя осень
#
# Loss: 0.6373113858699798
#  —
#  поднимая светлой ветвив.
#  Но и СПИД сойдет.
#
#  Порножурналы
#  Выписывать не стоит,
#  Если не стоит.
#
#  Как там Воркута?
#  Воркует и воруй!
#
#  Сукины с другом цвету.
#
#  Как и маразлес
#  не знаю, кто я
#
# Loss: 0.6434842658042907
#  веселые месть, нет.
#
#  Как быстро летит луна!
#  На самом ингану.
#
#  Нету запаха.
#  Увы, не сядет пчела
#  На заравыт пасон,
#  Соловей в ворон
#
#  Ты проснешься ты
#  проверяя скрипт
#
#  Переносную.
#  Сказала: В
# Loss: 0.635907883644104
#  —
#
#  Попала в колес0
#  Какая дрянь, но кони.
#  На свое напиться вспоминал
#  Но пенье! такать гейшу
#  Не поздняя осень
#
#  Порножурналы —
#  «Не вердит на Балу.
#
#  По болитви потом
#  сидим в темноте —
#  что при
# Loss: 0.6402023637294769
#  веселом.
#
#  Ворон, почивал.
#  Разве ж это жизнь?
#
#  Когда надо спать
#  Советский паспорт
#
#  От геморроя
#  прилег не спрятать в тихон
#  На поле маситья —
#  что так их тревочки
#
#  В небе высоком
#  но раздело
# Loss: 0.6367180931568146
#  назал
#  слапит в окно прости
#  страстно платила…
#
#  Друг все то она.
#  Да и пронес вишней травы
#  стал черно в рот на столен.
#  Посмотри скорей
#
#  слухи к серпла,
#  Голос цикады
#
#  пропил сапоги
#  теперь я н
# Loss: 0.6363665437698365
#  такаешь моей мальце
#  совсем ни капли
#
#  Не помню поставьте
#  А бесполеной зимой
#  Маленький Мойша
#
#  Не помню поставьте
#  А простой Акробова
#  Что гильотина…
#
#  Как японский бог
#  Зима — снег в небесай,
#  С
# Loss: 0.6423256671428681
#  такаешь моей вова
#  Тетерь сизует
#
#  сновидением
#  видели мне не стоит.
#  Не склоне гейша
#
#  Поднимусь лучше
#  застарал. гады.
#
#  Вот тебе и май!
#  не доволен я
#
#  Небеса на полдок.
#  Но и СПИД сойдет.
#
#  З
# Loss: 0.6395093917846679
#  Таковой ливые.
#  Проснулся в поле.
#
#  Старый правтра
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Старый ветерок?
#  Будет не чего
#  И полна принял
#
#  Уходи скорей!
#  Нет места смерти
#
#  Отдай мне деньги
#  На н
# Loss: 0.639807505607605
#  — как звездик. Додомился…
#
#  Стоит ли любить?
#  Стоит ли любить?
#
#  Стал тише воды.
#  Нет места смерти
#
#  Осень скорей!
#  ударили поднилась —
#  Витей вы кончило-с.
#  Постой праздник, Онан!
#
#  Когда надо сп
# Loss: 0.6338714075088501
#  —
#  поднимая светлой.
#  Сперва хоть тромбы
#
#  прыгаю в окно.
#  Осень на дворе…
#
#  Осенний вечер.
#  Не последняя ниже полбы
#  Нет — не хочу.
#
#  Плотно вад мне дороже
#  Начнется стихи, комень.
#  Лето — лавр в
# Loss: 0.6415475404262543
#  саду, как меня ник
#  Смотрю на луну.
#
#  Проголосовал.
#  Лучше бы в голове.
#
#  Как японский бог
#  Возразил Паваротти —
#  «Не хошь пришла моит веселая
#  голос цикады
#
#  пенье цикады.
#  а водкой посетре
#  Словн
# CPU times: user 15min 32s, sys: 8.98 s, total: 15min 41s
# Wall time: 15min 57s

# %% [markdown]
# Рекомендую поиграть с параметром temp и, конечно же, start_text. С помощью start_text можно попробовать «задать тему/направление» для генерируемого текста.

# %%
model.eval()

print(evaluate(
    model,
    char_to_idx,
    idx_to_char,
    temp=0.45,
    prediction_len=1000,
    start_text='Луна'
    )
)
# Out:
# Лунахвуй тихо микан,
#  Мой год утро…
#
#  Может и в ухо…
#  Вот скоро уходит
#
#  Любили его!
#  А он кустик последний глюки
#  Терзанья духа
#
#  любви все раздолба
#  вы обвежь! Диход
#
#  Нет места смерти
#  прохладно веселый
#
#  Как дальше жить мне?
#  Тоже все часто.
#
#  Старый правтра
#
#  От поцелуев…
#  Купит на ветках
#  И не помню, не смыслышки
#  и утии мороз.
#
#  Уж стоит ли любить?
#  Нет места смерти
#
#  Отдай водку промешкал
#  примчался верхом в Москву
#  Не подарит Дубинин
#  Голос цикады
#
#  паутину, мох
#  А в туалетется в полне
#  Сторит расстрыли со сегодня
#  сам расно спидете.
#
#  Тишина в короткий!
#  Пойду я трова
#  Помогайте друг другу прокушки
#  сам воздву помню,
#  Покупай Комбат
#
#  не получай.
#  Но и СПИД сойдет.
#
#  Прохладный ветер.
#  и с гор, парус или тужу,
#  Был в туалете
#
#  Пропил сапоги
#  теперь и вечен…
#
#  Пролетарии
#  вернись и жива?
#
#  Огород ин.
#  На ноге бомжа
#
#  проверяя скрипт,
#  но не надо света.
#
#  Плывут моей милой
#  Как японский бог
#
#  Как там Воркута?
#  Волкому махман я —
#  лебединая хлом.
#  Блин моя зайца в
